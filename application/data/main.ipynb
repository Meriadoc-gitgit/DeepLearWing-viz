# %% [markdown]
# # DeepLearWing Data Exploration
# ## Configurations préliminaires
# ### Installation des libraries requises

# %%
# Install required libraries

# Basic libraries
# !pip install numpy
# !pip install pandas

# For data access
# !pip install kagglehub
# Out:
# Requirement already satisfied: numpy in /Users/vuhoangthuyduong/miniconda3/lib/python3.12/site-packages (1.26.0)
# Requirement already satisfied: pandas in /Users/vuhoangthuyduong/miniconda3/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /Users/vuhoangthuyduong/miniconda3/lib/python3.12/site-packages (from pandas) (1.26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/vuhoangthuyduong/miniconda3/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/vuhoangthuyduong/miniconda3/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/vuhoangthuyduong/miniconda3/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /Users/vuhoangthuyduong/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: kagglehub in /Users/vuhoangthuyduong/miniconda3/lib/python3.12/site-packages (0.3.4)
# Requirement already satisfied: packaging in /Users/vuhoangthuyduong/miniconda3/lib/python3.12/site-packages (from kagglehub) (24.1)
# Requirement already satisfied: requests in /Users/vuhoangthuyduong/miniconda3/lib/python3.12/site-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in /Users/vuhoangthuyduong/miniconda3/lib/python3.12/site-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/vuhoangthuyduong/miniconda3/lib/python3.12/site-packages (from requests->kagglehub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/vuhoangthuyduong/miniconda3/lib/python3.12/site-packages (from requests->kagglehub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/vuhoangthuyduong/miniconda3/lib/python3.12/site-packages (from requests->kagglehub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/vuhoangthuyduong/miniconda3/lib/python3.12/site-packages (from requests->kagglehub) (2024.8.30)

# %% [markdown]
# ## Importation des libraries et package sources

# %%
# Import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set a Seaborn style
sns.set_theme(style="darkgrid")  # Options: "darkgrid", "whitegrid", "dark", "white", "ticks"

# Optional: Set a specific context for the plots (adjusts font size and other elements)
sns.set_context("notebook")  # Options: "paper", "notebook", "talk", "poster"


import os
import kagglehub

# Import packages for data manipulation
os.chdir(os.path.dirname(os.getcwd()))
from src.preprocess import *
# Out:
# 2024-12-14 09:15:31.256 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager

# %% [markdown]
# ---
#
# # **Data Exploration**

# %% [markdown]
# ### Chargement des données

# %%
# Chargement des données
print("Chargement des données")
data_path = "victorienmichel/deeplearwing"

# Download data
dataset_path = kagglehub.dataset_download(data_path)
print("Fin du téléchargement")

# Verify that the data has been downloaded
files = os.listdir(dataset_path)
print("Data path:",dataset_path)
print("Files in dataset directory:",files)

# Load data
csv_file = os.path.join(dataset_path, files[0])
df = pd.read_csv(csv_file)

print("Chargement avec succès")
# Out:
# Chargement des données
# Fin du téléchargement
# Data path: /Users/vuhoangthuyduong/.cache/kagglehub/datasets/victorienmichel/deeplearwing/versions/1
# Files in dataset directory: ['DeepLearWing.csv']
# Chargement avec succès

# %% [markdown]
# ### Description de l'ensemble des données de DeepLearWing.csv
# **Note**: Base de données en input, avant tout traitement de données
# #### Origine des données
#     URL du dataset: "https://www.kaggle.com/datasets/victorienmichel/deeplearwing?select=DeepLearWing.csv"
#
#     Data path sauvegardé dans l'environement de chacun: "/Users/{user}/.cache/kagglehub/datasets/victorienmichel/deeplearwing/versions/1"
#
# #### Nombre d'observations
#     819191
#
# #### Nombre de variables
#     8
#
# #### Types de variables avec leurs significations
# Cet ensemble de données contient des informations liées à l'aérodynamique des profils d'ailes, avec les colonnes suivantes :
#
# - **`name`** -- `object` : Le nom ou l'identifiant unique du profil d'aile.
# - **`angle`** -- `float64` : L'angle d'attaque (en degrés) du profil d'aile.
# - **`reynolds`** -- `int64` : Le nombre de Reynolds, qui caractérise le régime d'écoulement de l'air autour de l'aile.
# - **`x_coords`** -- 'object' : Coordonnées en X des points du profil d'aile (dans un repère 2D).
# - **`y_coords`** -- 'object' : Coordonnées en Y des points du profil d'aile (dans un repère 2D).
# - **`cd`** -- `float64` : Coefficient de traînée (Drag coefficient), une mesure de la résistance à l'écoulement.
# - **`cl`** -- `float64` : Coefficient de portance (Lift coefficient), une mesure de la force de portance générée.
# - **`cm`** -- `float64` : Coefficient de moment (Moment coefficient), lié au moment aérodynamique autour d'un point donné.
#
# #### Colonnes de données (total : 8 colonnes)
#
# | #  | Colonne   | Nombre de valeurs non nulles | Type de données |Nombre de valeurs manquantes|
# |----|-----------|------------------------------|-----------------|-|
# | 0  | `name`    | 819191                       | `object`        |0|
# | 1  | `angle`   | 819191                       | `float64`       |0|
# | 2  | `reynolds`| 819191                       | `int64`         |0|
# | 3  | `x_coords`| 819191                       | `object`        |0|
# | 4  | `y_coords`| 819191                       | `object`        |0|
# | 5  | `cd`      | 819191                       | `float64`       |0|
# | 6  | `cl`      | 819191                       | `float64`       |0|
# | 7  | `cm`      | 819191                       | `float64`       |0|
#
# #### Résumé des types de données
# - **Types** :
#   - `float64` : 4 colonnes
#   - `int64` : 1 colonne
#   - `object` : 3 colonnes
#
# #### Utilisation mémoire
# - La mémoire totale utilisée par cet ensemble de données est d'environ **50.0+ MB**.

# %%
# Affichage des 5 premières lignes
print("--------------------------------- DeepLearWing dataset ---------------------------------")
df.head(5)
# Out:
# --------------------------------- DeepLearWing dataset ---------------------------------
#     name  angle  reynolds                                           x_coords  \
# 0  2032c  -8.75    200000  1.0 0.95 0.9 0.8 0.7 0.6 0.5 0.4 0.3 0.25 0.2 ...
# 1  2032c  -8.50    200000  1.0 0.95 0.9 0.8 0.7 0.6 0.5 0.4 0.3 0.25 0.2 ...
# 2  2032c  -8.25    200000  1.0 0.95 0.9 0.8 0.7 0.6 0.5 0.4 0.3 0.25 0.2 ...
# 3  2032c  -8.00    200000  1.0 0.95 0.9 0.8 0.7 0.6 0.5 0.4 0.3 0.25 0.2 ...
# 4  2032c  -7.75    200000  1.0 0.95 0.9 0.8 0.7 0.6 0.5 0.4 0.3 0.25 0.2 ...
#
#                                             y_coords       cd      cl      cm
# 0  0.0016 0.0124 0.0229 0.0428 0.061 0.0771 0.090...  0.09761 -0.1581 -0.0262
# 1  0.0016 0.0124 0.0229 0.0428 0.061 0.0771 0.090...  0.09468 -0.1536 -0.0262
# 2  0.0016 0.0124 0.0229 0.0428 0.061 0.0771 0.090...  0.10671 -0.2407 -0.0219
# 3  0.0016 0.0124 0.0229 0.0428 0.061 0.0771 0.090...  0.10247 -0.2303 -0.0213
# 4  0.0016 0.0124 0.0229 0.0428 0.061 0.0771 0.090...  0.09947 -0.2229 -0.0215

# %% [markdown]
# ### shape__

# %%
print("Database dimensions:",df.shape)
print("---------------------\n")
print("Database information:")
print("---------------------")
df.info()
# Out:
# Database dimensions: (819191, 8)
# ---------------------
#
# Database information:
# ---------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 819191 entries, 0 to 819190
# Data columns (total 8 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   name      819191 non-null  object
#  1   angle     819191 non-null  float64
#  2   reynolds  819191 non-null  int64
#  3   x_coords  819191 non-null  object
#  4   y_coords  819191 non-null  object
#  5   cd        819191 non-null  float64
#  6   cl        819191 non-null  float64
#  7   cm        819191 non-null  float64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 50.0+ MB

# %% [markdown]
# ### describe__

# %%
df.describe()
# Out:
#                angle        reynolds             cd             cl  \
# count  819191.000000   819191.000000  819191.000000  819191.000000
# mean        2.196953   405215.755544       0.039202       0.444588
# std         8.217115   360658.569487       0.033895       0.741472
# min       -20.000000    50000.000000       0.002650      -2.289900
# 25%        -4.250000   100000.000000       0.014230      -0.185600
# 50%         2.250000   200000.000000       0.026530       0.499200
# 75%         8.750000   500000.000000       0.054970       1.095000
# max        20.750000  1000000.000000       0.591880       2.511300
#
#                   cm
# count  819191.000000
# mean       -0.050979
# std         0.050108
# min        -0.501000
# 25%        -0.081800
# 50%        -0.044700
# 75%        -0.015100
# max         0.278200

# %% [markdown]
# ### Gestion des valeurs manquantes

# %%
empty_before = df.isna().sum()
print(f"\nEmpty values (Before cleaning) :\n-------------------------------------\n{empty_before}")

remove_na_values(df)
df = refill_na_values(df)

empty_after = df.isna().sum()
print(f"\nEmpty values (After cleaning) :\n------------------------------------\n{empty_after}")
# Out:
# Empty values (Before cleaning) :
# -------------------------------------
# name        0
# angle       0
# reynolds    0
# x_coords    0
# y_coords    0
# cd          0
# cl          0
# cm          0
# dtype: int64
#
# Empty values (After cleaning) :
# ------------------------------------
# name        0
# angle       0
# reynolds    0
# x_coords    0
# y_coords    0
# cd          0
# cl          0
# cm          0
# dtype: int64

# %% [markdown]
# # **Data Extraction**

# %% [markdown]
# ## Explication de la Procédure du Code : `engineer_aerodynamic_features`
#
# Ce script Python implémente une fonction de **feature engineering** pour analyser et enrichir un dataset contenant des données aérodynamiques. Voici une explication pas-à-pas de la procédure.
#
#
# ### 1. Description de la fonction
#
# #### Signature :
# ```python
# def engineer_aerodynamic_features(
#     data_path: str,
#     sample_size: Optional[int] = None,
#     random_state: int = 42,
#     save_path: Optional[str] = None
# ) -> None:
# ```
#
# - **Objectif** : Transformer un dataset brut en ajoutant de nouvelles colonnes dérivées des données initiales.
# - **Arguments** :
#   - `data_path` (str) : Chemin vers le dataset source (format CSV, obtenu via Kaggle).
#   - `sample_size` (Optional[int]) : Nombre de lignes à conserver après traitement (par échantillonnage aléatoire).
#   - `random_state` (int) : Seed pour garantir la reproductibilité de l'échantillonnage.
#   - `save_path` (Optional[str]) : Chemin pour sauvegarder le fichier CSV résultant.
#
#
# ### 2. Étapes Principales
#
# #### Téléchargement et Chargement des Données
# - **Téléchargement depuis Kaggle** :
#   Utilisation de la bibliothèque `kagglehub` pour télécharger un dataset depuis le chemin spécifié.
#   ```python
#   dataset_path = kagglehub.dataset_download(data_path)
#   ```
#   Affiche les fichiers téléchargés dans le répertoire :
#   ```python
#   files = os.listdir(dataset_path)
#   ```
#
# - **Chargement dans un DataFrame Pandas** :
#   Lit le premier fichier CSV dans le répertoire téléchargé :
#   ```python
#   csv_file = os.path.join(dataset_path, files[0])
#   df = pd.read_csv(csv_file)
#   ```
#
#
# #### Liste des Opérations de Feature Engineering
# Une série de transformations est appliquée au dataset. Ces transformations sont définies par une liste de tuples contenant :
# 1. Une description de l'opération.
# 2. Une fonction `lambda` qui effectue le calcul correspondant.
#
# Exemples d'opérations :
# - **Lift-to-Drag Ratio** : `cl / cd`
# - **Angle x Reynolds** : `angle * reynolds`
# - **Logarithme de Reynolds** : `np.log(reynolds)`
# - **Angle au carré** : `angle^2`
#
# Code :
# ```python
# operations = [
#     ("Calcul du Lift-to-Drag Ratio", lambda df: df['cl'] / df['cd']),
#     ("Calcul de Angle x Reynolds", lambda df: df['angle'] * df['reynolds']),
#     # etc.
# ]
# new_columns = [
#     'Lift-to-Drag Ratio',
#     'Angle x Reynolds',
#     # etc.
# ]
# ```
#
#
#
# #### Application des Opérations
# Les transformations sont appliquées au DataFrame en ajoutant une colonne pour chaque nouvelle feature :
# ```python
# for (description, operation), col_name in tqdm(zip(operations, new_columns), total=len(operations), desc="Feature Engineering"):
#     df[col_name] = operation(df)
# ```
#
# - **Barre de progression** : La bibliothèque `tqdm` est utilisée pour afficher l'avancement.
#
# #### Échantillonnage
# Si un échantillonnage est demandé (`sample_size` non nul) :
# - Le DataFrame est réduit à un sous-ensemble aléatoire de `sample_size` lignes.
# - L'échantillonnage est reproductible grâce au paramètre `random_state`.
#
# Code :
# ```python
# if sample_size is not None:
#     df = df.sample(n=sample_size, random_state=random_state)
#     df.reset_index(inplace=True)
# ```
#
#
# #### Sauvegarde des Résultats
# Si un chemin de sauvegarde est fourni (`save_path`), les résultats sont enregistrés dans un fichier CSV :
# ```python
# if save_path:
#     df.to_csv(save_path, index=False)
# ```
#
#
# ## 3. Bibliothèques Utilisées
# - **Pandas** : Manipulation des données tabulaires.
# - **NumPy** : Calculs mathématiques.
# - **Tqdm** : Barre de progression pour afficher l’avancement.
# - **kagglehub** : Téléchargement automatique de datasets depuis Kaggle.
# - **os** : Gestion des fichiers et répertoires.
#
# ---
#
# ## Documentation de l'Ingénierie des Caractéristiques
#
# Ce document explique les nouvelles colonnes créées au cours du processus d'ingénierie des caractéristiques, ainsi que leurs formules respectives.
#
# ### 1. Rapport Portance-Trainée
#    - **Nom de la colonne :** `Lift-to-Drag Ratio`
#    - **Formule :**
#      $$
#      \text{Rapport Portance-Trainée} = \frac{\text{cl}}{\text{cd}}
#      $$
#    - **Description :**
#      Ce ratio représente l'efficacité aérodynamique, calculée comme le rapport entre le coefficient de portance (`cl`) et le coefficient de trainée (`cd`).
#
#
# ### 2. Angle x Reynolds
#    - **Nom de la colonne :** `Angle x Reynolds`
#    - **Formule :**
#      $$
#      \text{Angle x Reynolds} = \text{angle} \times \text{reynolds}
#      $$
#    - **Description :**
#      Cette caractéristique est le produit de l'angle d'attaque (`angle`) et du nombre de Reynolds (`reynolds`). Elle combine les effets des deux variables.
#
#
#
# ### 3. Log Reynolds
#    - **Nom de la colonne :** `Log Reynolds`
#    - **Formule :**
#      $$
#      \text{Log Reynolds} = \ln(\text{reynolds})
#      $$
#    - **Description :**
#      Cette colonne représente le logarithme naturel du nombre de Reynolds (`reynolds`).
#
#
# ### 4. Reynolds Normalisé
#    - **Nom de la colonne :** `Normalized Reynolds`
#    - **Formule :**
#      $$
#      \text{Reynolds Normalisé} = \frac{\text{reynolds} - \mu(\text{reynolds})}{\sigma(\text{reynolds})}
#      $$
#    - **Description :**
#      Cette valeur normalise le nombre de Reynolds en soustrayant la moyenne et en divisant par l'écart type.
#
#
#
# ### 5. Carré de l'Angle
#    - **Nom de la colonne :** `Angle^2`
#    - **Formule :**
#      $$
#      \text{Angle}^2 = (\text{angle})^2
#      $$
#    - **Description :**
#      Cette caractéristique correspond au carré de l'angle d'attaque (`angle`).
#
#
#
# ### 6. Valeur Absolue de l'Angle
#    - **Nom de la colonne :** `|Angle|`
#    - **Formule :**
#      $$
#      |\text{Angle}| = |\text{angle}|
#      $$
#    - **Description :**
#      Cette colonne représente la valeur absolue de l'angle d'attaque (`angle`).

# %%
featured_df = engineer_aerodynamic_features(
    df,
    sample_size=200000,
    save_path='data/feature_engineered_dataset.csv'
)
# Out:
# Début du feature engineering...
# Feature Engineering: 100%|██████████| 6/6 [00:00<00:00, 178.14it/s]
# Sélection aléatoire de 200000 échantillons...
# Feature engineering terminé!

# %% [markdown]
# ### Chargement des données

# %%
# featured_df = pd.read_csv("data/feature_engineered_dataset.csv")
print("Database dimension:",featured_df.shape)
featured_df.head(5)
# Out:
# Database dimension: (200000, 14)
#        name  angle  reynolds  \
# 0  fx84w127  13.00    200000
# 1     s8052  -7.50    100000
# 2    goe505  -7.75     50000
# 3   npl9660   9.50    200000
# 4  fx78k161 -11.25    500000
#
#                                             x_coords  \
# 0  1.0 0.99893 0.99572 0.99039 0.98296 0.97347 0....
# 1  1.0 0.99803 0.99231 0.98301 0.97022 0.95412 0....
# 2  1.0 0.94959 0.89918 0.7985 0.69791 0.5975 0.49...
# 3  1.0 0.997614 0.990418 0.9785 0.961985 0.941056...
# 4  1.0 0.99893 0.99572 0.99039 0.98296 0.97347 0....
#
#                                             y_coords       cd      cl      cm  \
# 0  0.0 0.00011 0.0005 0.0012 0.0023 0.00385 0.005...  0.05087  1.2399 -0.0276
# 1  0.0 0.00018 0.00079 0.00181 0.0033 0.00533 0.0...  0.05237 -0.6183 -0.0372
# 2  0.0 0.01784 0.03568 0.06537 0.09105 0.10874 0....  0.12606 -0.3704 -0.0127
# 3  0.0013 0.001763 0.002031 0.002194 0.00332 0.00...  0.02425  1.0313  0.0050
# 4  0.0 0.00103 0.00172 0.00262 0.00365 0.00488 0....  0.03212 -0.7401 -0.0718
#
#    Lift-to-Drag Ratio  Angle x Reynolds  Log Reynolds  Normalized Reynolds  \
# 0           24.373894         2600000.0     12.206073            -0.569003
# 1          -11.806378         -750000.0     11.512925            -0.846273
# 2           -2.938283         -387500.0     10.819778            -0.984909
# 3           42.527835         1900000.0     12.206073            -0.569003
# 4          -23.041719        -5625000.0     13.122363             0.262809
#
#     Angle^2  |Angle|
# 0  169.0000    13.00
# 1   56.2500     7.50
# 2   60.0625     7.75
# 3   90.2500     9.50
# 4  126.5625    11.25

# %% [markdown]
# ### Statistiques des coefficients aérodynamiques

# %%
featured_df[["cd", "cl", "cm"]].describe()
# Out:
#                   cd             cl             cm
# count  200000.000000  200000.000000  200000.000000
# mean        0.039237       0.443168      -0.051108
# std         0.033935       0.742487       0.050139
# min         0.002890      -2.252200      -0.501000
# 25%         0.014270      -0.187600      -0.081800
# 50%         0.026570       0.495600      -0.044800
# 75%         0.055030       1.095200      -0.015300
# max         0.591880       2.504000       0.278000

# %% [markdown]
# ### Matrice de corrélation

# %%
# Calculate the correlation matrix
correlation_matrix = featured_df[['angle', 'reynolds', 'cl', 'cd', 'cm']].corr()

# Streamlit App
# Display correlation matrix using a heatmap
fig, ax = plt.subplots(figsize=(8, 6))  # Adjust the figure size
sns.heatmap(correlation_matrix, annot=True, ax=ax, cbar_kws={'shrink': 0.8})

# Add title to the plot
plt.title('Correlation Matrix', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# #### Remarques sur la matrice de corrélation :
#
# 1. **Corrélations fortes** :
#    - **`angle` et `cl`** : Une forte corrélation positive (**0.918779**) est observée entre `angle` (angle d'attaque) et `cl` (coefficient de portance). Cela reflète une relation physique attendue : l'augmentation de l'angle d'attaque entraîne généralement une augmentation du coefficient de portance jusqu'à un certain point.
#
# 2. **Corrélations modérées** :
#    - **`cd` et `cm`** : Une corrélation modérée positive (**0.167736**) existe entre `cd` (coefficient de traînée) et `cm` (coefficient de moment). Cela peut indiquer que les variations du moment aérodynamique sont partiellement influencées par les forces de traînée.
#
# 3. **Corrélations faibles ou négligeables** :
#    - **`reynolds` et autres variables** :
#      - La corrélation entre `reynolds` et `cd` est négative (**-0.308374**), ce qui peut indiquer que des écoulements à faible nombre de Reynolds génèrent proportionnellement plus de traînée.
#      - Les autres corrélations impliquant `reynolds` sont faibles (proches de zéro), ce qui suggère que cette variable a un impact limité sur `cl` et `cm` dans ce dataset.
#
# 4. **Corrélations négatives** :
#    - **`cl` et `cm`** : Une corrélation négative (**-0.141940**) entre `cl` (portance) et `cm` (moment). Cela pourrait indiquer qu'une augmentation de la portance tend à réduire le moment aérodynamique, ce qui correspond à certains comportements physiques dans la conception d'ailes.
#
# 5. **Indépendance approximative** :
#    - Certaines paires de variables, comme `angle` et `cd` (**0.054096**), montrent des corrélations très faibles, suggérant qu'il y a peu ou pas de lien direct entre elles dans ce dataset.
#
# ##### Conclusion :
# La matrice met en évidence des relations physiques attendues, telles que la forte dépendance entre l'angle d'attaque et la portance, ainsi qu'une interaction notable entre le nombre de Reynolds et la traînée

# %% [markdown]
# ### Comparaison des statistiques entre le dataset complet et un échantillon

# %%
# Création de plusieurs tailles d'échantillons
sample_sizes = [1000, 5000, 10000]
stats_comparison = {}

# Statistiques du dataset complet
full_stats = {
    'cl_mean': df['cl'].mean(),
    'cl_std': df['cl'].std(),
    'cd_mean': df['cd'].mean(),
    'cd_std': df['cd'].std(),
    'corr_angle_cl': df['angle'].corr(df['cl'])
}

print("Comparaison des statistiques:")
print("\nDataset complet (n=50000):")
for k, v in full_stats.items():
    print(f"{k}: {v:.4f}")

for size in sample_sizes:
    sample = df.sample(n=size, random_state=42)
    print(f"\nÉchantillon (n={size}):")
    print(f"cl_mean: {sample['cl'].mean():.4f}")
    print(f"cl_std: {sample['cl'].std():.4f}")
    print(f"cd_mean: {sample['cd'].mean():.4f}")
    print(f"cd_std: {sample['cd'].std():.4f}")
    print(f"corr_angle_cl: {sample['angle'].corr(sample['cl']):.4f}")

# Vérification de la distribution des profils (name) dans les échantillons
print("\nNombre de profils uniques:")
print(f"Dataset complet: {df['name'].nunique()}")
for size in sample_sizes:
    sample = df.sample(n=size, random_state=42)
    print(f"Échantillon {size}: {sample['name'].nunique()}")
# Out:
# Comparaison des statistiques:
#
# Dataset complet (n=50000):
# cl_mean: 0.4446
# cl_std: 0.7415
# cd_mean: 0.0392
# cd_std: 0.0339
# corr_angle_cl: 0.9185
#
# Échantillon (n=1000):
# cl_mean: 0.4369
# cl_std: 0.7540
# cd_mean: 0.0389
# cd_std: 0.0344
# corr_angle_cl: 0.9174
#
# Échantillon (n=5000):
# cl_mean: 0.4474
# cl_std: 0.7430
# cd_mean: 0.0396
# cd_std: 0.0343
# corr_angle_cl: 0.9204
#
# Échantillon (n=10000):
# cl_mean: 0.4524
# cl_std: 0.7413
# cd_mean: 0.0396
# cd_std: 0.0341
# corr_angle_cl: 0.9180
#
# Nombre de profils uniques:
# Dataset complet: 1630
# Échantillon 1000: 750
# Échantillon 5000: 1536
# Échantillon 10000: 1623

# %% [markdown]
# #### Remarques sur la comparaison des statistiques :
#
# 1. **Stabilité des moyennes (`cl_mean` et `cd_mean`)** :
#    - Les moyennes pour `cl` et `cd` sont globalement proches des valeurs du dataset complet :
#      - **`cl_mean`** varie légèrement : plus faible pour l'échantillon de **1000** (**0.4369**) et plus élevée pour celui de **10000** (**0.4524**), mais reste très proche de la valeur globale (**0.4446**).
#      - **`cd_mean`** est également stable avec de petites variations : **0.0389** (échantillon 1000) à **0.0396** (échantillons 5000 et 10000).
#
# 2. **Écart-types (`cl_std` et `cd_std`)** :
#    - L'écart-type de `cl` varie légèrement dans les échantillons :
#      - Plus élevé pour l'échantillon de **1000** (**0.7540**), indiquant une plus grande dispersion dans ce sous-ensemble.
#      - Les échantillons plus grands (**5000** et **10000**) ont des écarts-types proches de celui du dataset complet (**0.7415**), reflétant mieux la distribution globale.
#
# 3. **Corrélation entre `angle` et `cl`** :
#    - La corrélation reste très stable dans tous les échantillons :
#      - Elle varie de **0.9174** (échantillon 1000) à **0.9204** (échantillon 5000), proche de la valeur globale de **0.9185**.
#
# 4. **Nombre de profils uniques** :
#    - Les échantillons plus petits (1000 et 5000) contiennent significativement moins de profils uniques que le dataset complet (**1630** profils) :
#      - **750 profils uniques** pour l'échantillon de **1000**, ce qui pourrait limiter la diversité.
#      - **1536 profils uniques** pour l'échantillon de **5000**, presque complet.
#      - **1623 profils uniques** pour l'échantillon de **10000**, proche de la couverture totale.
#
# ##### Conclusion :
# - Les échantillons de **5000** et **10000** capturent bien les caractéristiques du dataset complet, tant en termes de moyennes, d'écarts-types, que de corrélations.
# - L'échantillon de **1000** est moins représentatif, avec moins de profils uniques et une dispersion légèrement plus élevée dans `cl`.
# - Un échantillon de **5000 observations** semble être un compromis efficace entre représentativité et taille.

# %% [markdown]
# ---
#
# ## Avantages de l'échantillonnage
#
# ### Performance
# - **Temps d'exécution réduit** pour les visualisations.
# - **Moins de mémoire utilisée**, idéal pour les grandes données.
# - **Interactivité plus rapide**, particulièrement utile pour les outils interactifs.
#
# ### Visualisation
# - **Réduction de la superposition** dans les scatter plots.
# - **Lisibilité améliorée** pour observer les tendances générales.
#
# ### Risques et points d'attention
#
# ### Représentativité
# - Veiller à ce que **tous les profils d'aile soient inclus**.
# - Conserver la **distribution des angles d'attaque** et la **plage des nombres de Reynolds**.
#
# ### Perte potentielle d'information
# - Risque d'ignorer des **cas extrêmes** ou **comportements non linéaires subtils**.
# - Attention aux **transitions dans les régimes d'écoulement**.
#
# ## Recommandations
#
# - Utiliser un **échantillonnage stratifié** avec `n=10000` pour :
#   - Maintenir la **proportion des profils d'aile**.
#   - Préserver la **distribution des angles d'attaque** et les plages de **Reynolds**.
#
# ### Approche suggérée
# 1. **Exploration initiale / visualisations interactives** : Échantillon de 10 000 points.
# 2. **Analyses finales / statistiques** : Dataset complet.
# 3. **Animations** : Échantillon réduit à 5 000 points.
# 4. **Détection de cas particuliers** : Toujours analyser l'ensemble des données.
#
# > **Compromis optimal** entre performance et précision, tout en garantissant une bonne représentativité.
#
# ## Conclusion sur l'échantillonnage
#
# Un échantillon de **10 000 points (20% des données)** est optimal :
# - **Précision** : Erreur < 1% sur les statistiques principales.
# - **Performance** : Réduction significative du temps de calcul.
# - **Représentativité** : Relations entre variables conservées.

# %% [markdown]
# ## Explication Pas à Pas de la Fonction `create_stratified_sample`
# La fonction `create_stratified_sample` est conçue pour effectuer un **échantillonnage stratifié** sur un DataFrame Pandas contenant des données aérodynamiques. L'objectif est de préserver une représentation équilibrée des différentes sous-catégories du dataset tout en réduisant sa taille.
#
# ### Signature
# ```python
# def create_stratified_sample(df, n=10000):
# ```
# - **Arguments** :
#   - `df` : Le DataFrame source.
#   - `n` : Nombre total de lignes souhaitées après échantillonnage (par défaut, 10 000 lignes).
#
# - **Retour** :
#   - Un DataFrame échantillonné de manière stratifiée, de taille au plus `n` lignes.
#
#
# ### **1. Stratification**
#
# ##### **Création des Bins pour l'Angle et Reynolds**
# ```python
# df['angle_bin'] = pd.qcut(df['angle'], q=5, duplicates='drop')
# df['reynolds_bin'] = pd.qcut(df['reynolds'], q=5, duplicates='drop')
# ```
# - **`pd.qcut`** :
#   - Divise les valeurs continues en **quantiles** égaux (5 dans cet exemple).
#   - Crée des groupes appelés "bins" pour les colonnes :
#     - `angle` : Divise les angles en 5 intervalles (par ordre de grandeur).
#     - `reynolds` : Divise les valeurs de Reynolds en 5 intervalles.
#   - **Paramètre `duplicates='drop'`** : Si les valeurs uniques ne suffisent pas pour former les bins, les bins redondants sont supprimés.
#
# - **Ajout au DataFrame** :
#   - `angle_bin` : Colonne catégorique indiquant à quel quantile appartient chaque `angle`.
#   - `reynolds_bin` : Colonne catégorique pour les valeurs de `reynolds`.
#
#
#
# ### **2. Groupement par Catégories**
#
# #### **Définition des Groupes**
# ```python
# sample = df.groupby(['name', 'angle_bin', 'reynolds_bin']).apply(
#     lambda x: x.sample(n=max(1, int(n * len(x)/len(df))), random_state=42)
# ).reset_index(drop=True)
# ```
#
# - **Groupement** :
#   - Le DataFrame est regroupé selon :
#     - `name` : Nom du profil aérodynamique.
#     - `angle_bin` : Bin de l'angle.
#     - `reynolds_bin` : Bin de Reynolds.
#   - Chaque groupe représente une sous-catégorie spécifique dans le dataset.
#
# - **Échantillonnage au sein de chaque groupe** :
#   - **`apply`** : Applique une fonction sur chaque groupe.
#   - **`x.sample`** :
#     - Échantillonne des lignes dans chaque groupe.
#     - **Nombre d’échantillons** : Proportionnel à la taille relative du groupe dans le dataset initial :
#       ```python
#       n * len(x)/len(df)
#       ```
#       - Taille du groupe : `len(x)`
#       - Taille totale du DataFrame : `len(df)`
#     - Si un groupe est trop petit, au moins 1 ligne est échantillonnée grâce à `max(1, ...)`.
#     - La seed `random_state=42` garantit la reproductibilité.
#
# - **Réinitialisation des index** :
#   - **`reset_index(drop=True)`** : Supprime les index intermédiaires générés par le groupement.
#
#
#
# ### **3. Nettoyage**
#
# #### **Suppression des Colonnes Temporaires**
# ```python
# sample = sample.drop(['angle_bin', 'reynolds_bin'], axis=1)
# ```
# - Les colonnes `angle_bin` et `reynolds_bin`, créées uniquement pour la stratification, sont supprimées.
#
#
#
# ### **4. Ajustement Final de la Taille**
#
# #### **Limitation à `n` Lignes**
# ```python
# return sample.sample(n=min(n, len(sample)), random_state=42)
# ```
# - Si le DataFrame échantillonné contient plus de `n` lignes, il est réduit à `n` lignes supplémentaires par échantillonnage aléatoire.
# - Si le DataFrame contient déjà moins de `n` lignes, il est retourné tel quel.
#
#
#
# ### **Résumé :**
#
# La fonction :
# 1. Crée des bins pour les colonnes `angle` et `reynolds`.
# 2. Regroupe les données par `name`, `angle_bin`, et `reynolds_bin`.
# 3. Échantillonne proportionnellement dans chaque groupe pour préserver la distribution originale.
# 4. Supprime les colonnes temporaires utilisées pour la stratification.
# 5. Limite le DataFrame final à `n` lignes au maximum.

# %%
stratified_df = create_stratified_sample(
    featured_df, 
    n=200000, 
    save_path='data/echantillon_stratifie.csv'
)
# Out:
# Début du sample stratification..
# /Users/vuhoangthuyduong/Documents/SDA/Mining/DeepLearWing-viz/app/src/preprocess.py:139: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sample = df.groupby(['name', 'angle_bin', 'reynolds_bin']).apply(
# Sample stratification terminé!

# %% [markdown]
# ### Chargement de données

# %%
# stratified_df = pd.read_csv("data/echantillon_stratifie.csv")
print("Database dimension:",stratified_df.shape)
stratified_df.head(5)
# Out:
# Database dimension: (200000, 14)
#            name  angle  reynolds  \
# 119737   hs1620 -12.75   1000000
# 72272    goe233   5.25    200000
# 158154  nlf414f  -6.00    100000
# 65426    goe05k   8.00     50000
# 30074      e379   5.25   1000000
#
#                                                  x_coords  \
# 119737  1.0 0.99 0.98 0.97 0.96 0.95 0.94 0.93 0.92 0....
# 72272   1.0 0.94964 0.89932 0.79873 0.69822 0.59782 0....
# 158154  1.0 0.997947 0.991996 0.982311 0.968923 0.9520...
# 65426   1.0 0.95 0.9 0.8 0.7 0.6 0.5 0.4 0.3 0.2 0.15 ...
# 30074   1.0 0.99707 0.98827 0.97364 0.95339 0.92795 0....
#
#                                                  y_coords       cd      cl  \
# 119737  0.01272 0.01831 0.02353 0.0284 0.03295 0.03727...  0.01900 -0.9149
# 72272   0.00155 0.01646 0.03137 0.05849 0.08212 0.1005...  0.01799  1.4764
# 158154  0.000196 0.00039 0.001093 0.002343 0.004263 0....  0.06698 -0.6879
# 65426   0.0 0.00808 0.01387 0.02314 0.02941 0.03298 0....  0.10103  0.7944
# 30074   0.0 0.0002 0.00085 0.00214 0.00428 0.00739 0.0...  0.00832  1.1286
#
#             cm  Lift-to-Drag Ratio  Angle x Reynolds  Log Reynolds  \
# 119737 -0.1084          -48.152632       -12750000.0     13.815511
# 72272  -0.2037           82.067815         1050000.0     12.206073
# 158154 -0.0233          -10.270230         -600000.0     11.512925
# 65426  -0.0476            7.863011          400000.0     10.819778
# 30074  -0.0819          135.649038         5250000.0     13.815511
#
#         Normalized Reynolds   Angle^2  |Angle|
# 119737             1.649162  162.5625    12.75
# 72272             -0.569003   27.5625     5.25
# 158154            -0.846273   36.0000     6.00
# 65426             -0.984909   64.0000     8.00
# 30074              1.649162   27.5625     5.25

# %% [markdown]
# ### Statistiques des coefficients aéorodynamiques

# %%
stratified_df[["cd", "cl", "cm"]].describe()
# Out:
#                   cd             cl             cm
# count  200000.000000  200000.000000  200000.000000
# mean        0.039237       0.443168      -0.051108
# std         0.033935       0.742487       0.050139
# min         0.002890      -2.252200      -0.501000
# 25%         0.014270      -0.187600      -0.081800
# 50%         0.026570       0.495600      -0.044800
# 75%         0.055030       1.095200      -0.015300
# max         0.591880       2.504000       0.278000

# %% [markdown]
# ### Matrice de corrélation

# %%
# Calculate the correlation matrix
correlation_matrix = stratified_df[['angle', 'reynolds', 'cl', 'cd', 'cm']].corr()

# Streamlit App
# Display correlation matrix using a heatmap
fig, ax = plt.subplots(figsize=(8, 6))  # Adjust the figure size
sns.heatmap(correlation_matrix, annot=True, ax=ax, cbar_kws={'shrink': 0.8})

# Add title to the plot
plt.title('Correlation Matrix', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# # Fin de Data Exploration !

# %% [markdown]
# ---

# %%
from PyPDF2 import PdfReader

def read_pdf_pypdf2(file_path):
    reader = PdfReader(file_path)
    text = ""
    for page in reader.pages:
        text += page.extract_text()
    return text

pdf_text = read_pdf_pypdf2("541.pdf")
print(pdf_text)
# Out:
# 28TH INTERNATIONAL CONGRE SS OF THE AERONAUTIC AL SCIENCES
#
# 1
#
#
# Abstract
# The concept of joined -wing aircraft with
# nonplanar wings as conceived and patented by
# Wolkovitch is attractive due to various
# advantages such as light weight, high stiffness,
# low induced drag, high trimmed C Lmax , reduced
# wetted area and para site drag and good stability
# and control, which have been supported by
# independent analyses, design studies and wind
# tunnel tests. With such foreseen advantages the
# present work is carried out to design joined -wing
# business -jet aircraft and study and inves tigate its
# advantages and benefits as compared to the
# current available conventional business jet of
# similar size, passenger and payload capacity. In
# particular, the work searches for a conceptual
# design of joined -wing configured business -jet
# aircraft tha t possesses more superior
# characteristics and better aerodynamic
# performance in terms of increased lift and
# reduced drag, and lighter than the conventional
# business jet of similar size. Another significant
# objective of this work is to prove that the added
# rigidity possessed by the joined wing
# configuration can contribute to weight reduction.
# 1   Introduction
# The joined -wing [1, 2]  is an innovative aircraft
# configuration with a rear wing that has a tip that
# sweeps forward to join the trailing edge of the
# main  wing. The rear wing (aft wing or tail) is
# used both for pitch control and as a structural
# support for the forward wing. When compared to
# a conventional wing -tail configuration, several
# advantages have been predicted for joined -wings
# [3 - 9]. The potential  for lower structural weights and less drag are p erhaps  the most important of
# these advantages. The business jets promising
# market could benefit from various advantages
# offered by such benefits derived from joined -
# wing technology.
#   Joining the tail to th e wing allows the tail to act
# as a strut, relieving wing bending moments
# inboard of the wing -tail joint. The induce d
# buckling on the aft wing  structure , however, must
# be resisted with a stiffer structure, which could
# lead to weight  increase and need furthe r
# meticulous design compensation . Cuerno -Rejado
# et al [10] evaluates the capabilities of joined -
# wing medium -sized aircraft with tandem wings
# having positive and negative sweep and dihedral,
# and establish es a comparison with respect to a
# reference conventio nal wing -plus-horizontal tail
# aircraft  and with the same medium -/long -range
# transport mission.  The topics considered include
# structural arrangement, weights and aerodynamic
# characteristics, as well as operational issues, such
# as performance and direct oper ating costs. The
# conclusions drawn in this preliminary study are
# very positive, but further research is required in
# order to confirm some hypotheses regarding the
# structural arrangement.
#    In line with modern concern on efficiency,
# energy and environment , the objectives of the
# present work  is to contribute to the concept of
# “Better, Lighter, Faster, Cheaper and Greener”
# Joined -Wing Business -Jet aircraft. “Better”
# means the aircraft to be conceptually designed
# should possesses superior aerodynamic
# performa nce such as considerably good rate of
# climb and endurances, takeoff and landing
# distances, lower stalling velocity, and reduced
# drag, among others. “Faster” means that the
# aircraft is able to fly at a high speed, getting from CONCEPTUAL DESIGN  AND AERODYNAMIC STUDY
# OF JOINED -WING BUSINESS JET AIRCRAFT
#
# Kim Ern Foong * and Harijono Djojodihardjo**
# Universiti Putra Malaysia
# *Graduate, **Professor, and corresponding author; harijono@djojodihardjo.com
#
# Keywords : Joined Wing Aircraft, Aerodynamic, Aircraft Design, Computational Fluid
# Dynamics
#  Kim Ern Foong and Harijono Djojodihardjo
# 2 one point to another in a much  shorter time. In
# consequence, the aircraft should be able to fly in
# high-subsonic or transonic cruising speeds. If the
# joined -wing aircraft conceived should have
# considerably good aerodynamic performance,
# more fuel saving and economical engines with
# reduc ed thrust will be required, thus saving the
# aircraft’s operating cost, hence the word
# “Cheaper” comes into place. Greener aircraft
# objectives could be gained by all the previous
# advantages, as well as novel concept in the
# holistic design approach. Various authors [3 -9]
# have established and verified the advantages of
# Joined Wing Aircraft as c ompared to conventional
# Cantilevered Wing -Tail Design , such as l ighter
# weight wing structure , better directional stability and
# controllability , lower induced drag , impro ved
# aeroelastic characteristics  and i mproved space for
# fuel, which motivates the present work as well as
# poses a challenge for the conceptual design efforts. In
# summary, the objectives of the present work are  to
# carry out conceptual  design and aerodynamic  study of
# a joined -wing configuration aircraft that possesses
# better aerodynamic performance in terms of increased
# lift and reduced drag and lighter as compared to
# convention al business jet of similar size , passenger
# and payload capability , and to arrive a t a
# structurally robust joined wing configuration.
# 2  Statistical Studies for Reference Aircraft
# A comprehensive statistical study is carried out to
# search for some candidate business jets to be
# utilized as reference in establishing design
# requirements and  objectives  (DR&O), in-lieu of
# market study. The design parameters and
# performance specifications of several business jet
# were obtained from online literatures. One of
# these candidate business jets is selected as the
# conceptual design target, subject to fu rther
# overriding considerations , and reflects the
# specific DR &O based  on customer requirements,
# certification and other requirements.  For such
# purpose, a host of business jet aircraft data has
# been compiled and summarized in Table 1.  Based
# on such statist ical analysis on trends and state of
# the art, a Business Jet with specifications is
# described in Table 2 is obtained.
#
#  Table 1. A sample of Selected Business Jets
# Statistics (detailed analysis is elaborated in [11])
#
#
#
#  Table 2. Business Jet  Specificatio ns as outcome
# from the statistical analysis
#
# Parameters  Unit  Baseline  Intended
# Improveme
# nt
# No. of Passengers  Person  9 9
# Range  n mile  2,104.00  2,500.00
# Maximum Takeoff
# Gross Weight  lb 21,270.18  20,000.00
# Cruise Speed  mph 520.70  600.00
# Empty Weight  lb 14,420.00  13,000.00
# Service Ceiling  ft 46,218.25  48,000.00
# Price  USD  10,959,115.50  10,500,000.0
# 0
# Length  ft 53.87  52.00
# Height  ft 17.44  16.00
# Wing span  ft 54.72  54.00
# Wing area  ft 354.84  350.00
# Rate of Climb  ft/min  3568.32  3,600.00
# Takeoff Distance  ft 4,285.91  4,000.00
# Landing Distance  ft 3,086.21  3,000.00
#
# For the interest of objectivity, this reference
# Business Jet will be referred to in the present
# study as Reference Conventional Business Jet
# (RCBJ). It may be noted that the specification
# paramet ers of selected RCBJ  has a range of
# values  between Learjet  45 and Learjet 60, which
# for further assessment of the design study, will be
# referred .
# 3  CONCEPTUAL DESIGN  AND AERODYNAMIC STUDY
# OF JOINED -WING BUSINESS JET AI RCRAFT
#
#
#
# Fig. 1 . Learjet 60 as reference aircraft  [12]
#
#
#
# 3  Systematic  and Methodology: Conceptual
# Design  Approach .
# This work is organized systematically to cover
# the authors ’ design philosophy of th at of Raymer
# [13]. The state of the art and progress of the
# joined -wing aircraft technology and development
# are considered.  Following  a statistical analysis,
# performance and design parameters of various
# business jet aircrafts are carefully assessed and
# analyzed  to arrive at an acceptable target aircraft
# DR&O and  design specification s, which is then
# referred to as th e RCBJ.  The DR&O of this
# RCBJ will guide the present conceptual design to
# arrive at performance and design parameters of
# the desired Joined -Wing Business Jet (JWBJ). The design  considerations include  mission
# profile, weight and weight fraction  and wing
# loading determination, airfoil selection, thrust
# loading, engine selection, forewing sizing, centre
# of gravity determination, aft wing (horizontal
# tail) and fuselage sizing , and landing
# gear/undercarriage configuration determination.
#
#
#
# Further computation al iterations and analysis
# follow to obtain better estimation of aircraft
# weight, lift and drag. In addition, structural and
# stability analysis are also carried out in
# subsequent iterative cycles. A performance
# analysis is then ca rried out followed by
# comprehensive assess ment of the design
# specification s outcome .  This design philosophy
# is summarized in Figure 3. Following such
# design philosophies as a preliminary step toward
# CDIO, Lean Aircraft Initiatives, and “Better,
# Lighter, F aster, Cheaper and Greener” aircraft
# demanded by global energy and environmental
# concerns, the problem statement of this work is to
# conceptual ly design a joined -wing business jet
#
# Fig. 1.  Schematic of the Joined -Wing Business
# Jet Aircraft
# Fig. 3.  Summary of Conceptual Design
# Approach
# Fig. 2.  Schematic of the Joined -Wing
# Business Jet Aircraft
#  Kim Ern Foong and Harijono Djojodihardjo
# 4 aircraft that produces more lift  and less drag , but
# yet is lighter than the c onventional business jet of
# similar size.
# Mission profile determination  and Flight
# envelope of the joined -wing configuration
# aircraft
# The flight envelope, or V -n diagram, is
# determined following  FAR’s regulations and
# mission profile. The regulations provid e a
# method to determine the maximum load factor
# limit. The structure is designed to the ultimate
# load factor with a factor of safety of 1.5 above
# the limit load. Basically the V -n diagram is based
# on two limitations, namely aerodynamic and
# structural limit s. Some of the parameter s are
# incorporated  in the V -n diagram calculations. The
# improved and refined values are used instead of
# the initial estimate.
#
# Table 3. Parameters considered in flight envelope
# calculations
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0 123
# 4
# 5 635,000 ft/ 10,500m37,000 ft/11,100m
# 34,000 ft/10,200m
# 1800 seconds
# Fig. 4. Mission Profile  of the Target JWBJ
# 4  Conceptual Design Work Prog ress and
# Outcome
# 4.1   Aircraft Sizing ; Weight and Weight Fraction
# Determination
# The detail of the design calculation is
# comprehensively described in Kim[ 11]. The t otal
# weight of the p ayload, W paylo ad was determined to
# be 1635.00kg  (3604.56lb s), the range 4630 km
# and cruise velocity 550 mph.  The typical
# maximum lift -to-drag ratio,
# MaxL
# D
#   of RCBJ   is
# 14. An improvement in
# MaxL
# D
#   of 25% is desired.
# Assuming the JWBJ should acquire
# MaxL
# D
#  =1.75 ,
# its Lift-to-drag ratio during cruise  will be 15.155.
# The wing loading is computed based on two
# constrain ts: (a) Stall velocity , v stall  and (b)
# landing distance . Assuming an approach speed of
# similar to Learjet 60 , the velocity is  estimated to
# be 155.9km/hr. Typical cruise altitude of hcruise of
# 35000ft  and cruise Mach number of 0.8290 can
# be assumed.
#
# Wing loading based on Stall velocity
#
# To search for the desired CLmax.value and C L ,
# appropriate  selection of airfoil has to be made.
# Other parameters are estimated using those
# applicable to RCBJ.
# 5   Airfoil selection
# In order to start selecting a suitable airfoil  for
# conceptu al design purposes , airfoil analysis are Parameter s Units  Value  Remarks
#   17.5 Initial estimate
#   1.512  Obtained from
# airfoil
# Forewing Area, S
#  743.5649
#  (forewing)   0.07423  From Oswald span
# efficiency method
# Oswald Span Efficiency
# Factor,
#   (forewing)   0.4549  Oswald spa n
# efficiency method
#  (total aircraft)   0.0100094  Component
# buildup
# Cruise altitude
#  35000
# Cruise density
#  0.0007382
# Cruise velocity
#  806.6667
# Weight at mid -cruise
#  20019.0179  Improved value
# through lift and
# structural
# consideratio ns
# Wing loading
#
#  30.5073  Improved value
# Thrust loading
#
#  0.2414  Improved value
#
#
# 5  CONCEPTUAL DESIGN  AND AERODYNAMIC STUDY
# OF JOINED -WING BUSINESS JET AI RCRAFT
#
# carried out using basic principles and available simple
# computer program (for example designFOIL ).
# Following historical trends, the NACA 5 -digit series
# were used extensively in business jets. Thus, the
# NACA 5 -digit series airfoils were selected. NACA
# 66013 -43 airfoil w as selected due to its
# conventionality  and as a baseline .
# A parametric st udy is then carried out s tarting
# with NACA66013 -43 series , and its  values are varie d
# to find the best airfoil.  Such parametric s tudy is
# carried out varying the first, second and third, fourth
# and fifth digits, and other variations. Typical finding
# is illustrated by Table 4.
#
# Table 4. Typical Outcome of airfoil parametric
# study result
#
#
#
#
#
#
#
#
#
#
#
#
#
# For the example displayed in Tab le 4, the most
# suitable airfoil is NACA66013 -43 because it has a
# considerably high lift coefficient and also a drag
# coefficient that is not too large.  At the present stage,
# only parametric study for design iteration and
# optimization has been carried out; f urther structured
# optimization will be carried out incorporating wing
# twist and other structural considerations.  Wing
# loading study is exemplified in Table 5.
#
# Table 5, Wing Loading  estimates
#
# Constraints  Wing loading,
# W/S [lb/ft2]  Remarks
# Stall Velocity  30.2390  Lower wing
# loading
# Landing
# Distance  85.9830  Higher wing
# loading
#
# Based on such parametric study, forewing sizing
# is carried out, followed by the computation of
# wing area and aspect ratio. Trade -off study is
# made to choose the appropriate aspect ratio,
# taking into considerations the effect of aspect ratio on lift curve slope due to wing tip (trailing)
# vortices as qualitatively exhibited in Fig. 5.
# .
#
# Fig.5. The e ffect of aspect ratio to lift
#
# The figure above shows the relation between
#
# and the wetted aspect ratio. From  such graph and
# others available on various data bases,  a first estimate
# on the wingspan and aspect ratio can be made.
# The choice of wing dihedral angle should also be
# made, guided by dihedral angle guidelines as
# given by Raymer [13].  Since this joined -wing
# configuration is of low wing and it is a subsonic
# swept wing, the dihedral angles should be within
# 3 to 7 degrees.
# The forewing is placed in such as way that the
# aerodynamic centre of the wing is in line with the
# centre of gravity of the fuselage , as schematically
# illustrated by Fig.6. .
#
#
#
# Fig. 6. Schematic Diagram  of Forewing
# Placement
#
#  Variation of the lift coefficient indicated by
# the first digit
# [α=0˚]
# Type of airfoil  Lift
# Coeffic
# ient Drag
# Coeffici
# ent Moment
# Coefficie
# nt
# NACA46013 -43 0.436  0.0070  -0.064
# NACA56013 -43 0.544  0.0072  -0.080
# NACA66013 -43 0.653  0.0073  -0.097
# NACA76013 -43 0.724  0.0074  -0.113
# NACA86013 -43 0.766  0.0076  -0.129
#   Kim Ern Foong and Harijono Djojodihardjo
# 6
#
# Fig. 7: Schematic Diagram   of Fuselage  Design
# and dimensioning
#
# Table 6. Calculation of CG (without forewings)
#  Type of Weight
# Unit Weight [kg]
# Quantity
# Total [kg]
# Total [lbm]
# Distance from nose
# datum [ft]
# ∑
# Air crews  80 2 160 352.739619  8.02 2828.972
# Passengers  80 9 720 1587.32856  24.22  38445.1
# Cabin
# crew  80 2 160 352.73968  24.22  8543.355
# Cabin
# crew
# unchecked
# baggage  30 2 60 132.27738  39.34  5203.792
# Passenger
# unchecked
# baggage  5 9 45 99.208035  24.22  2402.819
# Air crew
# luggage  40 2 80 176.36984  8.02 1414.486
# Passenger
# checked
# luggage  30 9 270 595.24821  39.34  23417.06
# Engine  448.1492  2 896.29  1976.00034  40.6 80225.61
#     5271.91166   162481.2
#
# Forewing Airfoil
# The airfoil chosen for the forewing is . NACA
# 66013 -43 airfoil , shown in Fig. 8.
#
# Fig. 8. NACA 66013 -43 airfoil
#
#
# Fig. 9. Airfoil Maximum Thickness at Root Chord
# (dimensions in feet)
#
#
#
# Fig. 10. Aileron sizing and placement
#
# Through computation using strip theory, on -line
# simple airfoil comp utational method and panel
# method, wing lift and its parametric optimization is
# carried out.  The spanwise sectional lift distribution
# of the Conceptual JWBJ is exhibited in Fig s. 11 and
# 12..
#
#
#  Fig. 11 Distribution of Sectional Lift
# Distribution along forewing mid -span
# 7  CONCEPTUAL DESIGN  AND AERODYNAMIC STUDY
# OF JOINED -WING BUSINESS JET AI RCRAFT
#
#
#
# Thrust Loading Determination  and
# Determination of T hrust and Engine Selection
# The determination of the thrust loadi ng is based
# on three constrains: Takeoff Distance , Rate of
# Climb  and Maximum velocity at mid -cruise . The
# computational results are tabulated  in Table 7.
#
# Table 7. Engine selection
#
# Constrain
# Parameters  Thrust
# Required [lbf]  Ratio (T/W)
# Takeoff distance  1241.0472  0.09326
# Rate of Climb  4782.6760  0.35940
# Vmax at w mid-cruise 1661.5284  0.13070
#
# Thrust loading based on Rate of Climb has  been
# selected because the engines that will be selected later
# should  produce the thrust required at all points in the
# flights, which is critical during takeoff which
# requires largest  thrust  (5265.9072 lbf .).
#
# The maximum thrust is required occurs during rate -
# of-climb just after liftoff.  TRMax 5265.9072 lbf. The
# intended range for this aircraft is 2500 nautical miles
# (4630km) is considered long range and the type of
# aircraft falls under the transport aircraft category.
# According to the design requirements laid down by
# FAR, the number of engines required for aircraft
# which falls under the transport aircraft category must
# be more than 1 engine. Hence, 2 engines is selected to
# fulfill this requirement. It is also the trend that a
# business jet size aircraft have 2 engines. Thus, the
# thrust required per engine is
# (5265.98072lbf/2)=2632.9536lbf.
# Since the Federal Aviation Regulation states that two
# engines are required for long distance cruising , hence
# one engine must at least  provide 2632.9536lbf   during
# takeoff.  Running thr ough the engine specifications tabulated
# in [11] , two Honeywell TFE731 -60 are selected to be
# installed on this joined -wing configuration because
# not only both engines can produce the required
# maximum thrust of 5265.98072 lbf, but it is also
# significantly lighter as compared to other engines
# listed below.
# For the TFE731 -60 engine [53],  Length, L=1.27m(or
# 4.1667ft). Inlet Diameter, Dinlet=0.787m (2.5820ft) ;
# Maximum Diameter, Dmaximum =1.07 7m (3.5333 ft) ;
# 7   Fuselage Sizing
# The semimonocoque fuselage design was adopted
# since the semimonocoque design can enable the
# installation of any combination of longerons,
# stringers, bulkheads , and frames to reinforce the skin
# and maintain the cross -sectional shape of the fuselage.
# The skin plays a major role in resisting the shear load
# and together with the longitudinal members to resist
# tension and bending loads. Longerons help to resist
# most the fuselage bending loads while str ingers on the
# bending and stabilize the skin in time of compression.
# Bulkheads are used to overcome the concentrated load
# which is introduced unto the fuselage especially on
# the wing, landing gear, and tail surface attach points.
# This design eventually l eads to the rigidity and
# strength of the aircraft to be distributed evenly on the
# structure, thus making it stronger. It is also proven
# that this design may withstand considerable amount
# of damage and still remain strong and intact.
# The aisle have to be la rge enough based on safety
# requirement, so that all the passengers can
# disembark/escape from the aircraft in the case of
# emergency. Hence, it is important to have wider  aisle
# to ensure that the emergency evacuation of 90 second
# can be achieved.
# The fusela ge is usually divided up into three
# sections:  the nose cone, the cabin, and the tail cone.
# Typically the passengers are all housed in the cabin
# which tends to be in the shape of a right circular
# cylinder.  This shape is structurally sound, easy to
# manufa cture, permits increases in length by the
# addition of "plugs", and has reasonable drag
# characteristics.  The length of the cabin then depends
# upon the number of rows of seats desired and the
# pitch P of the rows, i.e. the longitudinal distance
# between adjac ent rows.  The number of rows is fixed
# by the number of seats abreast chosen for the design
# The fuselage layout is important in the design process
# as the length of the airplane depends on this. The
# length and diameter of the fuselage is related to the
# seating arrangement. The Fuselage of a passenger Fig. 11 Sectional lift coefficient distribution
# of the joined -wing configuration aircraft
# along forewing  mid-span  Kim Ern Foong and Harijono Djojodihardjo
# 8 airplane can be divided into four basic sections viz.
# nose, cockpit, payload compartment and tail fuselage.
# After comprehensive considerations, the nose length
# of the Learjet 60 is referred to be the nose length  of
# this joined -wing aircraft.
#
# Table 8. Fuselage parameters
#
# Fuselage Length  57.8483ft
# Fuselage Height Overall  5.7417ft
# Closure angle  6deg
# Upsweep Angle  14deg
# Nose length  10.9666ft
# Upsweep length  16.4213ft
#
# The cabin dimensions are referred to the d imensions
# of the Learjet 60. These values are adapted to the
# joined -wing aircraft design.
#
# Table 8. Cabin dimensions
#
# Length (from cockpit divider to end of
# pressurized compartment  24.04ft
# Width (centerline)  5.74ft
# Width (floorline)  3.94ft
# Height  4.87ft
#
#
# In the design of the cockpit, t he following factors
# are considered: Glass cockpit , for easy handl ing
# and less weight , as well as ergonomic from
# Pilot s’ point of  view , among others.  Other
# impression on the joined -wing configurations are
# exhibited in Figs. 12 -14.
#
#
#
# Fig. 12. Fuel tanks sizing and placement
# (dimensions in feet)
#
#
#
# Fig. 1 3. Fuel tank on forewing (dimensions in feet)
#
#
#
# Fig. 14. CG localization for landing gear
# placement
# 5   DETAILED CONCEPTUAL DESIGN
# 5.1   Winglet Effects
# Stretching w ingspan or increasing aspect ratio
# certainly reduces induced drag. Designers,
# though, have to balance the benefits of less
# induced drag against the costs of structural
# weight increases, more parasitic drag  or cost
# considerations. For the se reasons, aircraf t are
# fitted with winglets during the last two decades.
# Winglets work because they efficiently produce
# aerodynamic side forces that divert the inflow of
# air from the tip vortex. That takes a rather
# sophisticated small wing, one that is sized,
# shaped, cambe red and canted for a specific
# application and mounted on the wingtip where it
# will produce the most benefit and the least drag.
# A simple, large end plate would block the vortex,
# but an increase in span produces a much better
# lift-to-drag improvement becaus e it is a more -
# efficient lifting surface than a flat sheet of metal
# or composite.
# The winglet has a tip, just like a wing, so it also
# produces a tip vortex, although a much weaker
# one. The winglet's tip vortex is located far above
# the airflow over the wing , thus it has little
# influence on the airflow over the main wing ,
# 9  CONCEPTUAL DESIGN  AND AERODYNAMIC STUDY
# OF JOINED -WING BUSINESS JET AI RCRAFT
#
# hence Whitcomb reference of winglets as "vortex
# diffusers."
#
# Table   9. Considerations for winglets.
#
# TYPE OF JOINT  CONSIDERATION POINTS
# 1. Winglet extended
# above and below   Winglet having an ai rfoil section and
# being twisted and cambered to minimized
# induced drag [86].
#  Positive forewing dihedral angle allows
# larger winglets to be employed without
# ground clearance problems [87].
#
#  Trailing edge of forewing overlaps with
# leading edge aft wing minim izing
# interference drag [87].
#  Outer portion of forewing acts as slat for
# the outer portion of aft wing that
# improves tip -stalling characteristics [87].
#  Winglets designed to offset parasitic drag
# and weight penalties of the connecting
# structure by reducing  the airplane’s
# induced drag [87].
#  Winglets designed to develop sideways -
# acting loads even when the aircraft itself
# is not side -slipping [87].
#  Mutual bracing effect on the other wing
# due to the fact that a truss structure is
# formed. Strength to weight ra tio, and the
# stiffness of the aircraft is improved and
# the aerodynamic drag is reduced [87].
# 2. Circular cross
# section fairings   The fairings are streamlined hence the
# aerodynamic drag on the fairings are
# reduced [87].
#  Fairing can serve as fuel tank [87].
#  Fairing can serve as a container for bombs,
# missiles or other forms of payload or for
# landing gear [87].
# 3. Circular cross
# section fairings
# with winglets
# extended above
# and below   The functions are the same as the circular
# cross section fairings but a reduction  in
# induced drag [87] .
#
#
#
#
# Fig. 1 5. Plan-view of the joined -wing
# configuration aircraft - forewing and aftwings are
# joined with winglet extended above and below
# (dimensions in feet)
#  6   Structural Analysis
# Further to the study of the aerodynamic
# perfo rmance and weight reduction when all
# design parameters of the joined -wing
# configuration aircraft has been determined using
# RCBJ as a reference and to obtain better overall
# performance, structural loading on the critical
# parts of the joined -wing aircraft co nfiguration is
# analyzed. From such analysis, some
# modifications may have to be made, bearing in
# mind that the modified configuration has better
# performance . These are illustrated in Figs. 16 -18.
#
#
#
# Fig. 16  Forewing and aft wing dimensions when
# all design  parameters of the joined -wing
# configuration aircraft have been tuned to be
# comparable or better than the RCBJ, including
# structural considerations.
#
#
#
# Fig. 17. Vertical Tail Placement pre -adjustment
# and Placement and s izing of aft -wing  Conceptual
# Design Refinement
#  Kim Ern Foong and Harijono Djojodihardjo
# 10
#
# Fig. 18  Fuel Tank on Fore -wing  and Aileron
# Sizing and placement
# 7   Flight envelope of the joined -wing
# configuration aircraft
# The flight envelope, or V -n diagram, is
# determined a ccording to regulations in the FAR’s
# and from the mission profile. The regulations
# provide a method to determine the maximum
# limit load factor. The structure is designed to the
# ultimate load factor which has a factor of safety
# of 1.5 above the limit load. Basically v -n diagram
# were based on two limitations, namely
# aerodynamic limits and structural limits.  Some of
# the parameter are involved in the V -n diagram
# calculations. The improved and refined values are
# used instead of the initial estimate.
#
# Table 10  Parameters incorporated in flight
# envelope calculations
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Table 11. Summary of JWBJ Design
# Specification  as compared to RCBJ.
#
# Parameter  Unit  Joined -Wing
# Configuration
# Aircraft  RCBJ
# Number of passengers   - 9 9
# Range  n mile 2500.6252  2409.0000
# Maximum Range  n mile  2601.5674  2450.0000
# Maximum Takeoff Gross
# Weight  lbm 22684.1299  23500.0000
# Cruise speed (35000ft)  mph 550.0000  484.0000
# Stall velocity at sea -level  ft/s 130.4044  129.8300
# Stall velocity at 35000ft  ft/s 180.0000  -
# Maximum Operating
# Speed  ft/s 1030.0000  765.6000
# Serving Ceiling  ft 52651.8000  51000.0000
# Takeoff Distance  ft 2603.7323  4000
# Landing Distance  ft 2339.9544  2660.76
# Fuselage Length  ft 57.8483  58.6667
# Wing Span  ft 76.4200  47.7500
# Wing Area (For ewing)  sq. ft  743.5649  264.5
# Wing Area (Aft wing)  sq. ft  310.2954
#
#
# Parameters  Units  Value  Remarks
#  (L/D) max  17.5 Initial estimate
#  (CL)max  1.512  Obtained from
# airfoil
# Forewing Area, S  ft2 743.5649
#  (forewing)   0.07423  From Oswald
# span efficiency
# method
# Oswald Span Efficiency
# Factor,
#   (forewing)   0.4549  Oswald span
# efficiency method
#  (total aircraft)   0.0100094  Component
# buildup
# Cruise altitude  ft 35000
# Cruise density  Slug/ft3 0.0007382
# Cruise velocity  ft/s 806.6667
# Weight at mid -cruise  lb 20019.0179  Improved value
# through lift and
# structural
# considerations
# Wing loading (W/S)  lb/ ft2 30.5073  Improved value
# Thrust loading (T/W)  lbf/lbm 0.2414  Improved value
#  Flight Envelope of RCBJ  Fig. 18  Flight Envelope of JWBJ at 35000 ft
#
# Fig. 1 9  Flight Envelope of RCBJ at 35000 ft
#
# 11  CONCEPTUAL DESIGN  AND AERODYNAMIC STUDY
# OF JOINED -WING BUSINESS JET AI RCRAFT
#
# 6   Conclusions
# As concluding remarks, results obtained in both
# designs will be compared with the aim of
# concluding if the joined -wing configuration has
# met the objectives set out in th e beginning of this
# work. To this end, the comparison will be
# established based on four technological aspects.
# It is important to note that the conclusions drawn
# from this study are based on simplistic
# aerodynamic and structural assumptions that
# should be more accurately substantiated in future
# works.
# From the analysis carried out in this work , it can
# be concluded that,  the JWBJ joined -wing
# configuration aircraft is 5.0716 percent lighter
# than the reference Business Jet (RCBJ) and
# produces 1.3629 time s more  lift than the Learjet
# 60. The total drag of the joined -wing
# configuration aircraft after considering the
# reduction of vortex drag due to the joined -
# configuration is 3.5 percent lower than the
# Learjet 60. Figs. 18 and 19 and Table 11 exhibit
# such compariso n, which indicate that the
# objectives have been to a certain extent achieved.
# However, further study needs to be carried out to
# elaborate how joined -wing aircraft without any
# uplift produced by the aft wing will not turn out
# to be as heavy as the conventi onal design.
# References
# [1]. Wolkovitch, J., Joined Wing Aircraft, U.S. Patent
# 3,942,747, March 1976.
# [2]. Wolkovitch, J., Joined Wing Aircraft, U.S. Patent
# 4,365,773, Dec. 1982.
# [3]. Wolkovitch, J . The Joined Wing: An Overview,
# AIAA paper - 45285 -587, J.Aircraft , 23(3),  pp161 -
# 178, 1986 .
# [4]. Samuels, M.F., "Structural Weight Comparison of a
# Joined Wing and a Conventional Wing," Journal of
# Aircraft, Vol. 19, pp. 485 -491, 1982 .
# [5]. Gallman,  J., Smith , S. and  Kroo , I. Optimization of
# Joined -Wing Aircraft,  J Aircraft , Vol. 30, No. 6 ,
# 1993.
# [6]. Kroo, I., Gallman, J., and Smith, S. Aerodynamic
# and structural studies of joined -wing aircraft. Journal
# of Aircraft ,Vol. 28, No. 1, 74 –81, 1991.
# [7]. Gallman, J.W.,Smith, S. C.,and Kroo, I. M.
# Optimization of joined -wing aircraft. J. Aircr., 1993,
# 30(6) , 897 –905.
# [8]. Kroo, I. M.  Non-planar wing concept for increased
# aircraft efficiency”, VKI Lecture, 2005.  [9]. Kroo, I.M. Drag Due To Lift: Concepts for
# Prediction  and Reduction, Annu. Rev. Fluid Mech.
# 33:587 –617, 2001.
# [10]. Cuerno -Rejado, C., Alonso -Albir, L. and Gehse , P.
# Conceptual design of a medium -sized joined -wing
# aircraft , Proc. IMechE Vol. 224 Part G : J. Aerospace
# Engineering ,2007.
# [11]. Kim, E.F., Design and aerodynamic study of Joined -
# Wing Aircraft, Thesis, Aerospace Engineering
# Department, Universiti Putra Malayisa , 2011.
# [12]. Learjet 60, Wikimedia Foundation, Inc. 22 March
# 2011. 29 March 2011, http://en.wikipedia.org/
# wiki/Learjet_60 , accessed 15 June 2012.
# [13]. Raymer,  D.P. Aircraft Design: A Conceptual
# Approach ,  2nd Ed.. AIAA, USA, 1992.
# Acknowledgement
# The authors would like to thank Universiti Putra
# Malaysia (UPM) for granting Research
# University Grant Scheme (RUGS) No. 05 -02-10-
# 0928RU; CC -91933, under which the present
# research is carried out.
# Copyright Statemen t
# The authors confirm that they, and/or their company or
# organization, hold copyright on all of the original material
# included in this paper. The authors also confirm that they
# have obtained permission, from the copyright holder of any
# third party material  included in this paper, to publish it as
# part of their paper. The authors confirm that they give
# permission, or have obtained permission from the copyright
# holder of this paper, for the publication and distribution of
# this paper as part of the ICAS2012 pr oceedings or as
# individual off -prints from the proceedings.

# %%
import pdfplumber

def read_pdf_pdfplumber(file_path):
    text = ""
    with pdfplumber.open(file_path) as pdf:
        for page in pdf.pages:
            text += page.extract_text()
    return text

pdf_text = read_pdf_pdfplumber("541.pdf")
print(pdf_text)
# Out:
# 28TH INTERNATIONAL CONGRESS OF THE AERONAUTICAL SCIENCES
# CONCEPTUAL DESIGN AND AERODYNAMIC STUDY
# OF JOINED-WING BUSINESS JET AIRCRAFT
# Kim Ern Foong* and Harijono Djojodihardjo**
# Universiti Putra Malaysia
# *Graduate, **Professor, and corresponding author; harijono@djojodihardjo.com
# Keywords: Joined Wing Aircraft, Aerodynamic, Aircraft Design, Computational Fluid
# Dynamics
# Abstract and less drag are perhaps the most important of
# these advantages. The business jets promising
# The concept of joined-wing aircraft with
# market could benefit from various advantages
# nonplanar wings as conceived and patented by
# offered by such benefits derived from joined-
# Wolkovitch is attractive due to various
# wing technology.
# advantages such as light weight, high stiffness,
# Joining the tail to the wing allows the tail to act
# low induced drag, high trimmed C , reduced
# Lmax as a strut, relieving wing bending moments
# wetted area and parasite drag and good stability
# inboard of the wing-tail joint. The induced
# and control, which have been supported by
# buckling on the aft wing structure, however, must
# independent analyses, design studies and wind
# be resisted with a stiffer structure, which could
# tunnel tests. With such foreseen advantages the
# lead to weight increase and need further
# present work is carried out to design joined-wing
# meticulous design compensation. Cuerno-Rejado
# business-jet aircraft and study and investigate its
# et al [10] evaluates the capabilities of joined-
# advantages and benefits as compared to the
# wing medium-sized aircraft with tandem wings
# current available conventional business jet of
# having positive and negative sweep and dihedral,
# similar size, passenger and payload capacity. In
# and establishes a comparison with respect to a
# particular, the work searches for a conceptual
# reference conventional wing-plus-horizontal tail
# design of joined-wing configured business-jet
# aircraft and with the same medium-/long-range
# aircraft that possesses more superior
# transport mission. The topics considered include
# characteristics and better aerodynamic
# structural arrangement, weights and aerodynamic
# performance in terms of increased lift and
# characteristics, as well as operational issues, such
# reduced drag, and lighter than the conventional
# as performance and direct operating costs. The
# business jet of similar size. Another significant
# conclusions drawn in this preliminary study are
# objective of this work is to prove that the added
# very positive, but further research is required in
# rigidity possessed by the joined wing
# order to confirm some hypotheses regarding the
# configuration can contribute to weight reduction.
# structural arrangement.
# In line with modern concern on efficiency,
# energy and environment, the objectives of the
# 1 Introduction
# present work is to contribute to the concept of
# The joined-wing[1, 2] is an innovative aircraft “Better, Lighter, Faster, Cheaper and Greener”
# configuration with a rear wing that has a tip that Joined-Wing Business-Jet aircraft. “Better”
# sweeps forward to join the trailing edge of the means the aircraft to be conceptually designed
# main wing. The rear wing (aft wing or tail) is should possesses superior aerodynamic
# used both for pitch control and as a structural performance such as considerably good rate of
# support for the forward wing. When compared to climb and endurances, takeoff and landing
# a conventional wing-tail configuration, several distances, lower stalling velocity, and reduced
# advantages have been predicted for joined-wings drag, among others. “Faster” means that the
# [3 - 9]. The potential for lower structural weights aircraft is able to fly at a high speed, getting from
# 1Kim Ern Foong and Harijono Djojodihardjo
# one point to another in a much shorter time. In Table 1. A sample of Selected Business Jets
# consequence, the aircraft should be able to fly in Statistics (detailed analysis is elaborated in [11])
# high-subsonic or transonic cruising speeds. If the
# joined-wing aircraft conceived should have
# considerably good aerodynamic performance,
# more fuel saving and economical engines with
# reduced thrust will be required, thus saving the
# aircraft’s operating cost, hence the word
# “Cheaper” comes into place. Greener aircraft
# objectives could be gained by all the previous
# advantages, as well as novel concept in the
# holistic design approach. Various authors [3-9]
# have established and verified the advantages of
# Joined Wing Aircraft as compared to conventional
# Cantilevered Wing-Tail Design, such as lighter
# weight wing structure, better directional stability and
# controllability, lower induced drag, improved
# aeroelastic characteristics and improved space for
# fuel, which motivates the present work as well as
# poses a challenge for the conceptual design efforts. In
# summary, the objectives of the present work are to Table 2. Business Jet Specifications as outcome
# carry out conceptual design and aerodynamic study of from the statistical analysis
# a joined-wing configuration aircraft that possesses
# better aerodynamic performance in terms of increased
# Intended
# lift and reduced drag and lighter as compared to Parameters Unit Baseline Improveme
# nt
# conventional business jet of similar size, passenger
# No. of Passengers Person 9 9
# and payload capability, and to arrive at a
# Range n mile 2,104.00 2,500.00
# structurally robust joined wing configuration.
# Maximum Takeoff
# lb 21,270.18 20,000.00
# Gross Weight
# Cruise Speed mph 520.70 600.00
# 2 Statistical Studies for Reference Aircraft
# Empty Weight lb 14,420.00 13,000.00
# A comprehensive statistical study is carried out to Service Ceiling ft 46,218.25 48,000.00
# search for some candidate business jets to be 10,500,000.0
# Price USD 10,959,115.50
# 0
# utilized as reference in establishing design
# Length ft 53.87 52.00
# requirements and objectives (DR&O), in-lieu of
# Height ft 17.44 16.00
# market study. The design parameters and
# Wing span ft 54.72 54.00
# performance specifications of several business jet
# were obtained from online literatures. One of Wing area ft 354.84 350.00
# these candidate business jets is selected as the Rate of Climb ft/min 3568.32 3,600.00
# conceptual design target, subject to further Takeoff Distance ft 4,285.91 4,000.00
# overriding considerations, and reflects the
# Landing Distance ft 3,086.21 3,000.00
# specific DR&O based on customer requirements,
# certification and other requirements. For such
# For the interest of objectivity, this reference
# purpose, a host of business jet aircraft data has Business Jet will be referred to in the present
# been compiled and summarized in Table 1. Based
# study as Reference Conventional Business Jet
# on such statistical analysis on trends and state of (RCBJ). It may be noted that the specification
# the art, a Business Jet with specifications is
# parameters of selected RCBJ has a range of
# described in Table 2 is obtained. values between Learjet 45 and Learjet 60, which
# for further assessment of the design study, will be
# referred.
# 2CONCEPTUAL DESIGN AND AERODYNAMIC STUDY
# OF JOINED-WING BUSINESS JET AIRCRAFT
# The design considerations include mission
# profile, weight and weight fraction and wing
# loading determination, airfoil selection, thrust
# loading, engine selection, forewing sizing, centre
# of gravity determination, aft wing (horizontal
# tail) and fuselage sizing, and landing
# gear/undercarriage configuration determination.
# Fig. 1. Learjet 60 as reference aircraft [12]
# Fig.F 1ig. . S2c. h Semchaetmica otifc t hoef tJhoein Jeodin-Wedi-nWg iBnugs iness
# BusineJ se st A Jei tr c Ara irf ct
# raft
# Fig. 3. Summary of Conceptual Design
# Approach
# 3 Systematic and Methodology: Conceptual Further computational iterations and analysis
# Design Approach. follow to obtain better estimation of aircraft
# weight, lift and drag. In addition, structural and
# This work is organized systematically to cover
# stability analysis are also carried out in
# the authors’ design philosophy of that of Raymer
# subsequent iterative cycles. A performance
# [13]. The state of the art and progress of the
# analysis is then carried out followed by
# joined-wing aircraft technology and development
# comprehensive assessment of the design
# are considered. Following a statistical analysis,
# specifications outcome. This design philosophy
# performance and design parameters of various
# is summarized in Figure 3. Following such
# business jet aircrafts are carefully assessed and
# design philosophies as a preliminary step toward
# analyzed to arrive at an acceptable target aircraft
# CDIO, Lean Aircraft Initiatives, and “Better,
# DR&O and design specifications, which is then
# Lighter, Faster, Cheaper and Greener” aircraft
# referred to as the RCBJ. The DR&O of this
# demanded by global energy and environmental
# RCBJ will guide the present conceptual design to
# concerns, the problem statement of this work is to
# arrive at performance and design parameters of
# conceptually design a joined-wing business jet
# the desired Joined-Wing Business Jet (JWBJ).
# 3Kim Ern Foong and Harijono Djojodihardjo
# aircraft that produces more lift and less drag, but
# yet is lighter than the conventional business jet of
# similar size.
# Mission profile determination and Flight
# 37,000 ft/11,100m
# envelope of the joined-wing configuration
# 35,000 ft/ 10,500m 3
# aircraft 2 4
# The flight envelope, or V-n diagram, is 34,000 ft/10,200m
# determined following FAR’s regulations and
# mission profile. The regulations provide a
# 5 6
# method to determine the maximum load factor
# 0 1
# limit. The structure is designed to the ultimate 1800 seconds
# Fig. 4. Mission Profile of the Target JWBJ
# load factor with a factor of safety of 1.5 above
# the limit load. Basically the V-n diagram is based
# on two limitations, namely aerodynamic and
# 4 Conceptual Design Work Progress and
# structural limits. Some of the parameters are
# Outcome
# incorporated in the V-n diagram calculations. The
# improved and refined values are used instead of 4.1 Aircraft Sizing; Weight and Weight Fraction
# the initial estimate. Determination
# The detail of the design calculation is
# Table 3. Parameters considered in flight envelope comprehensively described in Kim[ 11]. The total
# calculations weight of the payload, W was determined to
# payload
# be 1635.00kg (3604.56lbs), the range 4630 km
# and cruise velocity 550 mph. The typical
# Parameters Units Value Remarks  L 
# maximum lift-to-drag ratio, of RCBJ is
#  
# D
# 17.5 Initial estimate Max
#  L 
# Obtained from
# 14. An improvement in
#  
# of 25% is desired.
# 1.512
# airfoil
# D
# Max
# Forewing Area, S 743.5649
# Assuming the JWBJ should acquire
#  L 
# =1.75,
# (forewing) 0.07423
# F efr fo im
# cie
# O ncs yw mald
# et
# hsp oa dn  D
#  Max
# Oswald Span Efficiency Oswald span its Lift-to-drag ratio during cruise will be 15.155.
# 0.4549
# Factor, (forewing) efficiency method The wing loading is computed based on two
# (total aircraft) 0.0100094 C buo im ldp uo pn ent constraints: (a) Stall velocity, v stall and (b)
# landing distance. Assuming an approach speed of
# Cruise altitude 35000
# similar to Learjet 60 , the velocity is estimated to
# Cruise density 0.0007382 be 155.9km/hr. Typical cruise altitude of h cruise of
# 35000ft and cruise Mach number of 0.8290 can
# Cruise velocity 806.6667
# be assumed.
# Improved value
# through lift and
# Wing loading based on Stall velocity
# Weight at mid-cruise 20019.0179
# structural
# considerations
# To search for the desired C Lmax.value and C
# L
# ,
# Wing loading 30.5073 Improved value appropriate selection of airfoil has to be made.
# Other parameters are estimated using those
# applicable to RCBJ.
# Thrust loading 0.2414 Improved value
# 5 Airfoil selection
# In order to start selecting a suitable airfoil for
# conceptual design purposes, airfoil analysis are
# 4CONCEPTUAL DESIGN AND AERODYNAMIC STUDY
# OF JOINED-WING BUSINESS JET AIRCRAFT
# carried out using basic principles and available simple ratio on lift curve slope due to wing tip (trailing)
# computer program (for example designFOIL). vortices as qualitatively exhibited in Fig. 5.
# Following historical trends, the NACA 5-digit series .
# were used extensively in business jets. Thus, the
# NACA 5-digit series airfoils were selected. NACA
# 66013-43 airfoil was selected due to its
# conventionality and as a baseline.
# A parametric study is then carried out starting
# with NACA66013-43 series, and its values are varied
# to find the best airfoil. Such parametric study is
# carried out varying the first, second and third, fourth
# and fifth digits, and other variations. Typical finding
# is illustrated by Table 4.
# 
# Table 4. Typical Outcome of airfoil parametric
# study result Fig.5. The effect of aspect ratio to lift
# Variation of the lift coefficient indicated by The figure above shows the relation between
# the first digit
# [α=0˚] and the wetted aspect ratio. From such graph and
# Lift Drag Moment others available on various data bases, a first estimate
# Type of airfoil Coeffic Coeffici Coefficie on the wingspan and aspect ratio can be made.
# ient ent nt
# The choice of wing dihedral angle should also be
# NACA46013-43 0.436 0.0070 -0.064
# made, guided by dihedral angle guidelines as
# NACA56013-43 0.544 0.0072 -0.080
# given by Raymer [13]. Since this joined-wing
# NACA66013-43 0.653 0.0073 -0.097
# configuration is of low wing and it is a subsonic
# NACA76013-43 0.724 0.0074 -0.113 swept wing, the dihedral angles should be within
# NACA86013-43 0.766 0.0076 -0.129 3 to 7 degrees.
# The forewing is placed in such as way that the
# For the example displayed in Table 4, the most aerodynamic centre of the wing is in line with the
# suitable airfoil is NACA66013-43 because it has a
# centre of gravity of the fuselage, as schematically
# considerably high lift coefficient and also a drag
# illustrated by Fig.6..
# coefficient that is not too large. At the present stage,
# only parametric study for design iteration and
# optimization has been carried out; further structured
# optimization will be carried out incorporating wing
# twist and other structural considerations. Wing
# loading study is exemplified in Table 5.
# Table 5, Wing Loading estimates
# Wing loading,
# Constraints Remarks
# W/S [lb/ft2]
# Lower wing
# Stall Velocity 30.2390
# loading
# Landing Higher wing
# 85.9830
# Distance loading
# Fig. 6. Schematic Diagram of Forewing
# Based on such parametric study, forewing sizing Placement
# is carried out, followed by the computation of
# wing area and aspect ratio. Trade-off study is
# made to choose the appropriate aspect ratio,
# taking into considerations the effect of aspect
# 5Kim Ern Foong and Harijono Djojodihardjo
# Fig. 8. NACA 66013-43 airfoil
# Fig. 7: Schematic Diagram of Fuselage Design
# and dimensioning
# Table 6. Calculation of CG (without forewings)
# Fig. 9. Airfoil Maximum Thickness at Root Chord
# (dimensions in feet)
# t h g ie W
# f o e p y T
# ] g k [ t h
# g ie W t in U
# y titn
# a u Q
# ]g k
# [ la t o T
# ]m b
# l[ la t o T
# e
# s o n m o
# r f e c n a t s
# iD]tf [
# m u t a d ∑
# Air crews 80 2 160 352.739619 8.02 2828.972
# Passengers 80 9 720 1587.32856 24.22 38445.1
# Cabin
# 80 2 160 352.73968 24.22 8543.355
# crew
# Cabin
# crew
# unchecked 30 2 60 132.27738 39.34 5203.792 Fig. 10. Aileron sizing and placement
# baggage
# Through computation using strip theory, on-line
# Passenger
# unchecked 5 9 45 99.208035 24.22 2402.819 simple airfoil computational method and panel
# baggage
# method, wing lift and its parametric optimization is
# Air crew carried out. The spanwise sectional lift distribution
# 40 2 80 176.36984 8.02 1414.486
# luggage
# of the Conceptual JWBJ is exhibited in Figs. 11 and
# Passenger
# checked 30 9 270 595.24821 39.34 23417.06 12..
# luggage
# Engine 448.1492 2 896.29 1976.00034 40.6 80225.61
# 5271.91166 162481.2
# Forewing Airfoil
# The airfoil chosen for the forewing is . NACA
# 66013-43 airfoil, shown in Fig. 8.
# Fig. 11 Distribution of Sectional Lift
# Distribution along forewing mid-span
# 6CONCEPTUAL DESIGN AND AERODYNAMIC STUDY
# OF JOINED-WING BUSINESS JET AIRCRAFT
# Running through the engine specifications tabulated
# in [11], two Honeywell TFE731-60 are selected to be
# installed on this joined-wing configuration because
# not only both engines can produce the required
# maximum thrust of 5265.98072lbf, but it is also
# significantly lighter as compared to other engines
# listed below.
# For the TFE731-60 engine [53], Length, L=1.27m(or
# 4.1667ft). Inlet Diameter, D =0.787m (2.5820ft);
# inlet
# Maximum Diameter, D maximum=1.077m (3.5333 ft);
# Fig. 11 Sectional lift coefficient distribution
# of the joined-wing configuration aircraft
# Thrust Loading Determination and 7 Fuselage Sizing
# along forewing mid-span
# The semimonocoque fuselage design was adopted
# since the semimonocoque design can enable the
# Determination of Thrust and Engine Selection
# installation of any combination of longerons,
# The determination of the thrust loading is based stringers, bulkheads, and frames to reinforce the skin
# and maintain the cross-sectional shape of the fuselage.
# on three constrains: Takeoff Distance, Rate of
# The skin plays a major role in resisting the shear load
# Climb and Maximum velocity at mid-cruise. The
# and together with the longitudinal members to resist
# computational results are tabulated in Table 7.
# tension and bending loads. Longerons help to resist
# most the fuselage bending loads while stringers on the
# Table 7. Engine selection
# bending and stabilize the skin in time of compression.
# Bulkheads are used to overcome the concentrated load
# Constrain Thrust Ratio (T/W) which is introduced unto the fuselage especially on
# Parameters Required [lbf]
# the wing, landing gear, and tail surface attach points.
# Takeoff distance 1241.0472 0.09326
# This design eventually leads to the rigidity and
# Rate of Climb 4782.6760 0.35940
# strength of the aircraft to be distributed evenly on the
# V at w 1661.5284 0.13070
# max mid-cruise structure, thus making it stronger. It is also proven
# that this design may withstand considerable amount
# Thrust loading based on Rate of Climb has been
# of damage and still remain strong and intact.
# selected because the engines that will be selected later
# The aisle have to be large enough based on safety
# should produce the thrust required at all points in the
# requirement, so that all the passengers can
# flights, which is critical during takeoff which
# disembark/escape from the aircraft in the case of
# requires largest thrust (5265.9072 lbf.).
# emergency. Hence, it is important to have wider aisle
# The maximum thrust is required occurs during rate- to ensure that the emergency evacuation of 90 second
# of-climb just after liftoff. T 5265.9072 lbf. The can be achieved.
# RMax
# The fuselage is usually divided up into three
# intended range for this aircraft is 2500 nautical miles
# sections: the nose cone, the cabin, and the tail cone.
# (4630km) is considered long range and the type of
# aircraft falls under the transport aircraft category. Typically the passengers are all housed in the cabin
# According to the design requirements laid down by which tends to be in the shape of a right circular
# cylinder. This shape is structurally sound, easy to
# FAR, the number of engines required for aircraft
# which falls under the transport aircraft category must manufacture, permits increases in length by the
# be more than 1 engine. Hence, 2 engines is selected to addition of "plugs", and has reasonable drag
# characteristics. The length of the cabin then depends
# fulfill this requirement. It is also the trend that a
# upon the number of rows of seats desired and the
# business jet size aircraft have 2 engines. Thus, the
# thrust required per engine is pitch P of the rows, i.e. the longitudinal distance
# (5265.98072lbf/2)=2632.9536lbf. between adjacent rows. The number of rows is fixed
# by the number of seats abreast chosen for the design
# Since the Federal Aviation Regulation states that two
# engines are required for long distance cruising, hence The fuselage layout is important in the design process
# one engine must at least provide 2632.9536lbf during as the length of the airplane depends on this. The
# length and diameter of the fuselage is related to the
# takeoff.
# seating arrangement. The Fuselage of a passenger
# 7Kim Ern Foong and Harijono Djojodihardjo
# airplane can be divided into four basic sections viz.
# nose, cockpit, payload compartment and tail fuselage.
# After comprehensive considerations, the nose length
# of the Learjet 60 is referred to be the nose length of
# this joined-wing aircraft.
# Table 8. Fuselage parameters
# Fuselage Length 57.8483ft
# Fuselage Height Overall 5.7417ft
# Closure angle 6deg
# Upsweep Angle 14deg Fig. 13. Fuel tank on forewing (dimensions in feet)
# Nose length 10.9666ft
# Upsweep length 16.4213ft
# The cabin dimensions are referred to the dimensions
# of the Learjet 60. These values are adapted to the
# joined-wing aircraft design.
# Table 8. Cabin dimensions
# Fig. 14. CG localization for landing gear
# Length (from cockpit divider to end of 24.04ft
# placement
# pressurized compartment
# Width (centerline) 5.74ft
# Width (floorline) 3.94ft
# Height 4.87ft 5 DETAILED CONCEPTUAL DESIGN
# In the design of the cockpit, the following factors 5.1 Winglet Effects
# are considered: Glass cockpit, for easy handling
# Stretching wingspan or increasing aspect ratio
# and less weight, as well as ergonomic from
# certainly reduces induced drag. Designers,
# Pilots’ point of view, among others. Other
# though, have to balance the benefits of less
# impression on the joined-wing configurations are
# induced drag against the costs of structural
# exhibited in Figs. 12-14.
# weight increases, more parasitic drag or cost
# considerations. For these reasons, aircraft are
# fitted with winglets during the last two decades.
# Winglets work because they efficiently produce
# aerodynamic side forces that divert the inflow of
# air from the tip vortex. That takes a rather
# sophisticated small wing, one that is sized,
# shaped, cambered and canted for a specific
# application and mounted on the wingtip where it
# will produce the most benefit and the least drag.
# A simple, large end plate would block the vortex,
# but an increase in span produces a much better
# lift-to-drag improvement because it is a more-
# Fig. 12. Fuel tanks sizing and placement
# efficient lifting surface than a flat sheet of metal
# (dimensions in feet)
# or composite.
# The winglet has a tip, just like a wing, so it also
# produces a tip vortex, although a much weaker
# one. The winglet's tip vortex is located far above
# the airflow over the wing, thus it has little
# influence on the airflow over the main wing,
# 8CONCEPTUAL DESIGN AND AERODYNAMIC STUDY
# OF JOINED-WING BUSINESS JET AIRCRAFT
# hence Whitcomb reference of winglets as "vortex 6 Structural Analysis
# diffusers."
# Further to the study of the aerodynamic
# performance and weight reduction when all
# Table 9. Considerations for winglets.
# design parameters of the joined-wing
# configuration aircraft has been determined using
# TYPE OF JOINT CONSIDERATION POINTS
# 1. Winglet extended  Winglet having an airfoil section and RCBJ as a reference and to obtain better overall
# above and below being twisted and cambered to minimized
# performance, structural loading on the critical
# induced drag [86].
#  Positive forewing dihedral angle allows parts of the joined-wing aircraft configuration is
# larger winglets to be employed without
# analyzed. From such analysis, some
# ground clearance problems [87].
# modifications may have to be made, bearing in
#  Trailing edge of forewing overlaps with
# mind that the modified configuration has better
# leading edge aft wing minimizing
# interference drag [87]. performance. These are illustrated in Figs. 16-18.
#  Outer portion of forewing acts as slat for
# the outer portion of aft wing that
# improves tip-stalling characteristics [87].
#  Winglets designed to offset parasitic drag
# and weight penalties of the connecting
# structure by reducing the airplane’s
# induced drag [87].
#  Winglets designed to develop sideways-
# acting loads even when the aircraft itself
# is not side-slipping [87].
#  Mutual bracing effect on the other wing
# due to the fact that a truss structure is
# formed. Strength to weight ratio, and the
# stiffness of the aircraft is improved and
# the aerodynamic drag is reduced [87].
# 2. Circular cross  The fairings are streamlined hence the
# section fairings aerodynamic drag on the fairings are Fig. 16 Forewing and aft wing dimensions when
# reduced [87]. all design parameters of the joined-wing
#  Fairing can serve as fuel tank [87].
# configuration aircraft have been tuned to be
#  Fairing can serve as a container for bombs,
# missiles or other forms of payload or for comparable or better than the RCBJ, including
# landing gear [87].
# structural considerations.
# 3. Circular cross  The functions are the same as the circular
# section fairings cross section fairings but a reduction in
# with winglets induced drag [87] .
# extended above
# and below
# Fig. 15. Plan-view of the joined-wing
# configuration aircraft - forewing and aftwings are
# Fig. 17. Vertical Tail Placement pre-adjustment
# joined with winglet extended above and below
# and Placement and sizing of aft-wing Conceptual
# (dimensions in feet)
# Design Refinement
# 9Kim Ern Foong and Harijono Djojodihardjo
# Fig. 18 Fuel Tank on Fore-wing and Aileron
# Sizing and placement
# 7 Flight envelope of the joined-wing
# Fig. 18 Flight Envelope of JWBJ at 35000 ft
# configuration aircraft
# The flight envelope, or V-n diagram, is
# Flight Envelope of RCBJ
# determined according to regulations in the FAR’s
# and from the mission profile. The regulations
# provide a method to determine the maximum
# limit load factor. The structure is designed to the
# ultimate load factor which has a factor of safety
# of 1.5 above the limit load. Basically v-n diagram
# were based on two limitations, namely
# aerodynamic limits and structural limits. Some of
# the parameter are involved in the V-n diagram
# calculations. The improved and refined values are
# Fig. 19 Flight Envelope of RCBJ at 35000 ft
# used instead of the initial estimate.
# Table 11. Summary of JWBJ Design
# Table 10 Parameters incorporated in flight Specification as compared to RCBJ.
# envelope calculations
# Joined-Wing
# Configuration
# Parameter Unit Aircraft RCBJ
# Parameters Units Value Remarks
# Number of passengers - 9 9
# (L/D)max 17.5 Initial estimate
# Obtained from Range n mile 2500.6252 2409.0000
# (CL)max 1.512
# airfoil
# Forewing Area, S ft2 743.5649
# Maximum Range n mile 2601.5674 2450.0000
# Maximum Takeoff Gross
# From Oswald Weight lbm 22684.1299 23500.0000
# (forewing) 0.07423 span efficiency
# method Cruise speed (35000ft) mph 550.0000 484.0000
# Oswald Span Efficiency
# 0.4549
# Oswald span
# Stall velocity at sea-level ft/s 130.4044 129.8300
# Factor, (forewing) efficiency method
# Component Stall velocity at 35000ft ft/s 180.0000 -
# (total aircraft) 0.0100094
# buildup Maximum Operating
# Cruise altitude ft 35000 Speed ft/s 1030.0000 765.6000
# Cruise density Slug/ft3 0.0007382 Serving Ceiling ft 52651.8000 51000.0000
# Cruise velocity ft/s 806.6667 Takeoff Distance ft 2603.7323 4000
# Improved value Landing Distance ft 2339.9544 2660.76
# through lift and
# Weight at mid-cruise lb 20019.0179
# structural Fuselage Length ft 57.8483 58.6667
# considerations
# Wing loading (W/S) lb/ ft2 30.5073 Improved value Wing Span ft 76.4200 47.7500
# Thrust loading (T/W) lbf/lbm 0.2414 Improved value Wing Area (Forewing) sq. ft 743.5649 264.5
# Wing Area (Aft wing) sq. ft 310.2954
# 10CONCEPTUAL DESIGN AND AERODYNAMIC STUDY
# OF JOINED-WING BUSINESS JET AIRCRAFT
# 6 Conclusions [9]. Kroo, I.M. Drag Due To Lift: Concepts for
# Prediction and Reduction, Annu. Rev. Fluid Mech.
# As concluding remarks, results obtained in both 33:587–617, 2001.
# [10]. Cuerno-Rejado, C., Alonso-Albir, L. and Gehse, P.
# designs will be compared with the aim of
# Conceptual design of a medium-sized joined-wing
# concluding if the joined-wing configuration has
# aircraft, Proc. IMechE Vol. 224 Part G: J. Aerospace
# met the objectives set out in the beginning of this
# Engineering,2007.
# work. To this end, the comparison will be [11]. Kim, E.F., Design and aerodynamic study of Joined-
# established based on four technological aspects. Wing Aircraft, Thesis, Aerospace Engineering
# Department, Universiti Putra Malayisa, 2011.
# It is important to note that the conclusions drawn
# [12]. Learjet 60, Wikimedia Foundation, Inc. 22 March
# from this study are based on simplistic
# 2011. 29 March 2011, http://en.wikipedia.org/
# aerodynamic and structural assumptions that
# wiki/Learjet_60, accessed 15 June 2012.
# should be more accurately substantiated in future [13]. Raymer, D.P. Aircraft Design: A Conceptual
# works. Approach, 2nd Ed.. AIAA, USA, 1992.
# From the analysis carried out in this work, it can
# be concluded that, the JWBJ joined-wing
# Acknowledgement
# configuration aircraft is 5.0716 percent lighter
# than the reference Business Jet (RCBJ) and
# The authors would like to thank Universiti Putra
# produces 1.3629 times more lift than the Learjet
# Malaysia (UPM) for granting Research
# 60. The total drag of the joined-wing
# University Grant Scheme (RUGS) No. 05-02-10-
# configuration aircraft after considering the
# 0928RU; CC-91933, under which the present
# reduction of vortex drag due to the joined-
# research is carried out.
# configuration is 3.5 percent lower than the
# Learjet 60. Figs. 18 and 19 and Table 11 exhibit
# such comparison, which indicate that the Copyright Statement
# objectives have been to a certain extent achieved.
# The authors confirm that they, and/or their company or
# However, further study needs to be carried out to
# organization, hold copyright on all of the original material
# elaborate how joined-wing aircraft without any
# included in this paper. The authors also confirm that they
# uplift produced by the aft wing will not turn out have obtained permission, from the copyright holder of any
# to be as heavy as the conventional design. third party material included in this paper, to publish it as
# part of their paper. The authors confirm that they give
# permission, or have obtained permission from the copyright
# holder of this paper, for the publication and distribution of
# References
# this paper as part of the ICAS2012 proceedings or as
# individual off-prints from the proceedings.
# [1]. Wolkovitch, J., Joined Wing Aircraft, U.S. Patent
# 3,942,747, March 1976.
# [2]. Wolkovitch, J., Joined Wing Aircraft, U.S. Patent
# 4,365,773, Dec. 1982.
# [3]. Wolkovitch, J. The Joined Wing: An Overview,
# AIAA paper - 45285-587, J.Aircraft, 23(3), pp161-
# 178, 1986.
# [4]. Samuels, M.F., "Structural Weight Comparison of a
# Joined Wing and a Conventional Wing," Journal of
# Aircraft, Vol. 19, pp. 485-491, 1982.
# [5]. Gallman, J., Smith, S. and Kroo, I. Optimization of
# Joined-Wing Aircraft, J Aircraft, Vol. 30, No. 6,
# 1993.
# [6]. Kroo, I., Gallman, J., and Smith, S. Aerodynamic
# and structural studies of joined-wing aircraft. Journal
# of Aircraft,Vol. 28, No. 1, 74–81, 1991.
# [7]. Gallman, J.W.,Smith, S. C.,and Kroo, I. M.
# Optimization of joined-wing aircraft. J. Aircr., 1993,
# 30(6), 897–905.
# [8]. Kroo, I. M. Non-planar wing concept for increased
# aircraft efficiency”, VKI Lecture, 2005.
# 11

# %%
import re

def extract_sections(text):
    # Regex to match headers
    header_pattern = r"(?<=\n)(\d+ [A-Za-z]+(?: [A-Za-z]+)*)"

    matches = list(re.finditer(header_pattern, text))

    sections = {}
    for i, match in enumerate(matches):
        start = match.end()
        end = matches[i + 1].start() if i + 1 < len(matches) else len(text)
        header = match.group().strip(': ')
        sections[header] = text[start:end].strip()
    
    return sections

sections = extract_sections(pdf_text)

# %%
sections
# Out:
# {'1 Introduction': 'present work is to contribute to the concept of\nThe joined-wing[1, 2] is an innovative aircraft “Better, Lighter, Faster, Cheaper and Greener”\nconfiguration with a rear wing that has a tip that Joined-Wing Business-Jet aircraft. “Better”\nsweeps forward to join the trailing edge of the means the aircraft to be conceptually designed\nmain wing. The rear wing (aft wing or tail) is should possesses superior aerodynamic\nused both for pitch control and as a structural performance such as considerably good rate of\nsupport for the forward wing. When compared to climb and endurances, takeoff and landing\na conventional wing-tail configuration, several distances, lower stalling velocity, and reduced\nadvantages have been predicted for joined-wings drag, among others. “Faster” means that the\n[3 - 9]. The potential for lower structural weights aircraft is able to fly at a high speed, getting from\n1Kim Ern Foong and Harijono Djojodihardjo\none point to another in a much shorter time. In Table 1. A sample of Selected Business Jets\nconsequence, the aircraft should be able to fly in Statistics (detailed analysis is elaborated in [11])\nhigh-subsonic or transonic cruising speeds. If the\njoined-wing aircraft conceived should have\nconsiderably good aerodynamic performance,\nmore fuel saving and economical engines with\nreduced thrust will be required, thus saving the\naircraft’s operating cost, hence the word\n“Cheaper” comes into place. Greener aircraft\nobjectives could be gained by all the previous\nadvantages, as well as novel concept in the\nholistic design approach. Various authors [3-9]\nhave established and verified the advantages of\nJoined Wing Aircraft as compared to conventional\nCantilevered Wing-Tail Design, such as lighter\nweight wing structure, better directional stability and\ncontrollability, lower induced drag, improved\naeroelastic characteristics and improved space for\nfuel, which motivates the present work as well as\nposes a challenge for the conceptual design efforts. In\nsummary, the objectives of the present work are to Table 2. Business Jet Specifications as outcome\ncarry out conceptual design and aerodynamic study of from the statistical analysis\na joined-wing configuration aircraft that possesses\nbetter aerodynamic performance in terms of increased\nIntended\nlift and reduced drag and lighter as compared to Parameters Unit Baseline Improveme\nnt\nconventional business jet of similar size, passenger\nNo. of Passengers Person 9 9\nand payload capability, and to arrive at a\nRange n mile 2,104.00 2,500.00\nstructurally robust joined wing configuration.\nMaximum Takeoff\nlb 21,270.18 20,000.00\nGross Weight\nCruise Speed mph 520.70 600.00',
#  '2 Statistical Studies for Reference Aircraft': 'Empty Weight lb 14,420.00 13,000.00\nA comprehensive statistical study is carried out to Service Ceiling ft 46,218.25 48,000.00\nsearch for some candidate business jets to be 10,500,000.0\nPrice USD 10,959,115.50\n0\nutilized as reference in establishing design\nLength ft 53.87 52.00\nrequirements and objectives (DR&O), in-lieu of\nHeight ft 17.44 16.00\nmarket study. The design parameters and\nWing span ft 54.72 54.00\nperformance specifications of several business jet\nwere obtained from online literatures. One of Wing area ft 354.84 350.00\nthese candidate business jets is selected as the Rate of Climb ft/min 3568.32 3,600.00\nconceptual design target, subject to further Takeoff Distance ft 4,285.91 4,000.00\noverriding considerations, and reflects the\nLanding Distance ft 3,086.21 3,000.00\nspecific DR&O based on customer requirements,\ncertification and other requirements. For such\nFor the interest of objectivity, this reference\npurpose, a host of business jet aircraft data has Business Jet will be referred to in the present\nbeen compiled and summarized in Table 1. Based\nstudy as Reference Conventional Business Jet\non such statistical analysis on trends and state of (RCBJ). It may be noted that the specification\nthe art, a Business Jet with specifications is\nparameters of selected RCBJ has a range of\ndescribed in Table 2 is obtained. values between Learjet 45 and Learjet 60, which\nfor further assessment of the design study, will be\nreferred.\n2CONCEPTUAL DESIGN AND AERODYNAMIC STUDY\nOF JOINED-WING BUSINESS JET AIRCRAFT\nThe design considerations include mission\nprofile, weight and weight fraction and wing\nloading determination, airfoil selection, thrust\nloading, engine selection, forewing sizing, centre\nof gravity determination, aft wing (horizontal\ntail) and fuselage sizing, and landing\ngear/undercarriage configuration determination.\nFig. 1. Learjet 60 as reference aircraft [12]\nFig.F 1ig. . S2c. h Semchaetmica otifc t hoef tJhoein Jeodin-Wedi-nWg iBnugs iness\nBusineJ se st A Jei tr c Ara irf ct\nraft\nFig. 3. Summary of Conceptual Design\nApproach',
#  '3 Systematic and Methodology': ': Conceptual Further computational iterations and analysis\nDesign Approach. follow to obtain better estimation of aircraft\nweight, lift and drag. In addition, structural and\nThis work is organized systematically to cover\nstability analysis are also carried out in\nthe authors’ design philosophy of that of Raymer\nsubsequent iterative cycles. A performance\n[13]. The state of the art and progress of the\nanalysis is then carried out followed by\njoined-wing aircraft technology and development\ncomprehensive assessment of the design\nare considered. Following a statistical analysis,\nspecifications outcome. This design philosophy\nperformance and design parameters of various\nis summarized in Figure 3. Following such\nbusiness jet aircrafts are carefully assessed and\ndesign philosophies as a preliminary step toward\nanalyzed to arrive at an acceptable target aircraft\nCDIO, Lean Aircraft Initiatives, and “Better,\nDR&O and design specifications, which is then\nLighter, Faster, Cheaper and Greener” aircraft\nreferred to as the RCBJ. The DR&O of this\ndemanded by global energy and environmental\nRCBJ will guide the present conceptual design to\nconcerns, the problem statement of this work is to\narrive at performance and design parameters of\nconceptually design a joined-wing business jet\nthe desired Joined-Wing Business Jet (JWBJ).\n3Kim Ern Foong and Harijono Djojodihardjo\naircraft that produces more lift and less drag, but\nyet is lighter than the conventional business jet of\nsimilar size.\nMission profile determination and Flight\n37,000 ft/11,100m\nenvelope of the joined-wing configuration\n35,000 ft/ 10,500m 3\naircraft 2 4\nThe flight envelope, or V-n diagram, is 34,000 ft/10,200m\ndetermined following FAR’s regulations and\nmission profile. The regulations provide a\n5 6\nmethod to determine the maximum load factor\n0 1\nlimit. The structure is designed to the ultimate 1800 seconds\nFig. 4. Mission Profile of the Target JWBJ\nload factor with a factor of safety of 1.5 above\nthe limit load. Basically the V-n diagram is based\non two limitations, namely aerodynamic and',
#  '4 Conceptual Design Work Progress and': 'structural limits. Some of the parameters are\nOutcome\nincorporated in the V-n diagram calculations. The\nimproved and refined values are used instead of 4.1 Aircraft Sizing; Weight and Weight Fraction\nthe initial estimate. Determination\nThe detail of the design calculation is\nTable 3. Parameters considered in flight envelope comprehensively described in Kim[ 11]. The total\ncalculations weight of the payload, W was determined to\npayload\nbe 1635.00kg (3604.56lbs), the range 4630 km\nand cruise velocity 550 mph. The typical\nParameters Units Value Remarks \uf0e6 L \uf0f6\nmaximum lift-to-drag ratio, of RCBJ is\n\uf0e7 \uf0f7\n\uf0e8D\uf0f8\n17.5 Initial estimate Max\n\uf0e6 L \uf0f6\nObtained from\n14. An improvement in\n\uf0e7 \uf0f7\nof 25% is desired.\n1.512\nairfoil\n\uf0e8D\uf0f8\nMax\nForewing Area, S 743.5649\nAssuming the JWBJ should acquire\n\uf0e6 L \uf0f6\n=1.75,\n(forewing) 0.07423\nF efr fo im\ncie\nO ncs yw mald\net\nhsp oa dn \uf0e7 \uf0e8D\uf0f7\n\uf0f8 Max\nOswald Span Efficiency Oswald span its Lift-to-drag ratio during cruise will be 15.155.\n0.4549\nFactor, (forewing) efficiency method The wing loading is computed based on two\n(total aircraft) 0.0100094 C buo im ldp uo pn ent constraints: (a) Stall velocity, v stall and (b)\nlanding distance. Assuming an approach speed of\nCruise altitude 35000\nsimilar to Learjet 60 , the velocity is estimated to\nCruise density 0.0007382 be 155.9km/hr. Typical cruise altitude of h cruise of\n35000ft and cruise Mach number of 0.8290 can\nCruise velocity 806.6667\nbe assumed.\nImproved value\nthrough lift and\nWing loading based on Stall velocity\nWeight at mid-cruise 20019.0179\nstructural\nconsiderations\nTo search for the desired C Lmax.value and C\nL\n,\nWing loading 30.5073 Improved value appropriate selection of airfoil has to be made.\nOther parameters are estimated using those\napplicable to RCBJ.\nThrust loading 0.2414 Improved value',
#  '5 Airfoil selection': 'In order to start selecting a suitable airfoil for\nconceptual design purposes, airfoil analysis are\n4CONCEPTUAL DESIGN AND AERODYNAMIC STUDY\nOF JOINED-WING BUSINESS JET AIRCRAFT\ncarried out using basic principles and available simple ratio on lift curve slope due to wing tip (trailing)\ncomputer program (for example designFOIL). vortices as qualitatively exhibited in Fig. 5.\nFollowing historical trends, the NACA 5-digit series .\nwere used extensively in business jets. Thus, the\nNACA 5-digit series airfoils were selected. NACA\n66013-43 airfoil was selected due to its\nconventionality and as a baseline.\nA parametric study is then carried out starting\nwith NACA66013-43 series, and its values are varied\nto find the best airfoil. Such parametric study is\ncarried out varying the first, second and third, fourth\nand fifth digits, and other variations. Typical finding\nis illustrated by Table 4.\n\uf061\nTable 4. Typical Outcome of airfoil parametric\nstudy result Fig.5. The effect of aspect ratio to lift\nVariation of the lift coefficient indicated by The figure above shows the relation between\nthe first digit\n[α=0˚] and the wetted aspect ratio. From such graph and\nLift Drag Moment others available on various data bases, a first estimate\nType of airfoil Coeffic Coeffici Coefficie on the wingspan and aspect ratio can be made.\nient ent nt\nThe choice of wing dihedral angle should also be\nNACA46013-43 0.436 0.0070 -0.064\nmade, guided by dihedral angle guidelines as\nNACA56013-43 0.544 0.0072 -0.080\ngiven by Raymer [13]. Since this joined-wing\nNACA66013-43 0.653 0.0073 -0.097\nconfiguration is of low wing and it is a subsonic\nNACA76013-43 0.724 0.0074 -0.113 swept wing, the dihedral angles should be within\nNACA86013-43 0.766 0.0076 -0.129 3 to 7 degrees.\nThe forewing is placed in such as way that the\nFor the example displayed in Table 4, the most aerodynamic centre of the wing is in line with the\nsuitable airfoil is NACA66013-43 because it has a\ncentre of gravity of the fuselage, as schematically\nconsiderably high lift coefficient and also a drag\nillustrated by Fig.6..\ncoefficient that is not too large. At the present stage,\nonly parametric study for design iteration and\noptimization has been carried out; further structured\noptimization will be carried out incorporating wing\ntwist and other structural considerations. Wing\nloading study is exemplified in Table 5.\nTable 5, Wing Loading estimates\nWing loading,\nConstraints Remarks\nW/S [lb/ft2]\nLower wing\nStall Velocity 30.2390\nloading\nLanding Higher wing\n85.9830\nDistance loading\nFig. 6. Schematic Diagram of Forewing\nBased on such parametric study, forewing sizing Placement\nis carried out, followed by the computation of\nwing area and aspect ratio. Trade-off study is\nmade to choose the appropriate aspect ratio,\ntaking into considerations the effect of aspect\n5Kim Ern Foong and Harijono Djojodihardjo\nFig. 8. NACA 66013-43 airfoil\nFig. 7: Schematic Diagram of Fuselage Design\nand dimensioning\nTable 6. Calculation of CG (without forewings)\nFig. 9. Airfoil Maximum Thickness at Root Chord\n(dimensions in feet)\nt h g ie W\nf o e p y T\n] g k [ t h\ng ie W t in U\ny titn\na u Q\n]g k\n[ la t o T\n]m b\nl[ la t o T\ne\ns o n m o\nr f e c n a t s\niD]tf [\nm u t a d ∑\nAir crews 80 2 160 352.739619 8.02 2828.972\nPassengers 80 9 720 1587.32856 24.22 38445.1\nCabin\n80 2 160 352.73968 24.22 8543.355\ncrew\nCabin\ncrew\nunchecked 30 2 60 132.27738 39.34 5203.792 Fig. 10. Aileron sizing and placement\nbaggage\nThrough computation using strip theory, on-line\nPassenger\nunchecked 5 9 45 99.208035 24.22 2402.819 simple airfoil computational method and panel\nbaggage\nmethod, wing lift and its parametric optimization is\nAir crew carried out. The spanwise sectional lift distribution\n40 2 80 176.36984 8.02 1414.486\nluggage\nof the Conceptual JWBJ is exhibited in Figs. 11 and\nPassenger\nchecked 30 9 270 595.24821 39.34 23417.0 ...
#  '7 Flight envelope of the joined': '-wing\nFig. 18 Flight Envelope of JWBJ at 35000 ft\nconfiguration aircraft\nThe flight envelope, or V-n diagram, is\nFlight Envelope of RCBJ\ndetermined according to regulations in the FAR’s\nand from the mission profile. The regulations\nprovide a method to determine the maximum\nlimit load factor. The structure is designed to the\nultimate load factor which has a factor of safety\nof 1.5 above the limit load. Basically v-n diagram\nwere based on two limitations, namely\naerodynamic limits and structural limits. Some of\nthe parameter are involved in the V-n diagram\ncalculations. The improved and refined values are\nFig. 19 Flight Envelope of RCBJ at 35000 ft\nused instead of the initial estimate.\nTable 11. Summary of JWBJ Design\nTable 10 Parameters incorporated in flight Specification as compared to RCBJ.\nenvelope calculations\nJoined-Wing\nConfiguration\nParameter Unit Aircraft RCBJ\nParameters Units Value Remarks\nNumber of passengers - 9 9\n(L/D)max 17.5 Initial estimate\nObtained from Range n mile 2500.6252 2409.0000\n(CL)max 1.512\nairfoil\nForewing Area, S ft2 743.5649\nMaximum Range n mile 2601.5674 2450.0000\nMaximum Takeoff Gross\nFrom Oswald Weight lbm 22684.1299 23500.0000\n(forewing) 0.07423 span efficiency\nmethod Cruise speed (35000ft) mph 550.0000 484.0000\nOswald Span Efficiency\n0.4549\nOswald span\nStall velocity at sea-level ft/s 130.4044 129.8300\nFactor, (forewing) efficiency method\nComponent Stall velocity at 35000ft ft/s 180.0000 -\n(total aircraft) 0.0100094\nbuildup Maximum Operating\nCruise altitude ft 35000 Speed ft/s 1030.0000 765.6000\nCruise density Slug/ft3 0.0007382 Serving Ceiling ft 52651.8000 51000.0000\nCruise velocity ft/s 806.6667 Takeoff Distance ft 2603.7323 4000\nImproved value Landing Distance ft 2339.9544 2660.76\nthrough lift and\nWeight at mid-cruise lb 20019.0179\nstructural Fuselage Length ft 57.8483 58.6667\nconsiderations\nWing loading (W/S) lb/ ft2 30.5073 Improved value Wing Span ft 76.4200 47.7500\nThrust loading (T/W) lbf/lbm 0.2414 Improved value Wing Area (Forewing) sq. ft 743.5649 264.5\nWing Area (Aft wing) sq. ft 310.2954\n10CONCEPTUAL DESIGN AND AERODYNAMIC STUDY\nOF JOINED-WING BUSINESS JET AIRCRAFT',
#  '6 Conclusions': '[9]. Kroo, I.M. Drag Due To Lift: Concepts for\nPrediction and Reduction, Annu. Rev. Fluid Mech.\nAs concluding remarks, results obtained in both 33:587–617, 2001.\n[10]. Cuerno-Rejado, C., Alonso-Albir, L. and Gehse, P.\ndesigns will be compared with the aim of\nConceptual design of a medium-sized joined-wing\nconcluding if the joined-wing configuration has\naircraft, Proc. IMechE Vol. 224 Part G: J. Aerospace\nmet the objectives set out in the beginning of this\nEngineering,2007.\nwork. To this end, the comparison will be [11]. Kim, E.F., Design and aerodynamic study of Joined-\nestablished based on four technological aspects. Wing Aircraft, Thesis, Aerospace Engineering\nDepartment, Universiti Putra Malayisa, 2011.\nIt is important to note that the conclusions drawn\n[12]. Learjet 60, Wikimedia Foundation, Inc. 22 March\nfrom this study are based on simplistic\n2011. 29 March 2011, http://en.wikipedia.org/\naerodynamic and structural assumptions that\nwiki/Learjet_60, accessed 15 June 2012.\nshould be more accurately substantiated in future [13]. Raymer, D.P. Aircraft Design: A Conceptual\nworks. Approach, 2nd Ed.. AIAA, USA, 1992.\nFrom the analysis carried out in this work, it can\nbe concluded that, the JWBJ joined-wing\nAcknowledgement\nconfiguration aircraft is 5.0716 percent lighter\nthan the reference Business Jet (RCBJ) and\nThe authors would like to thank Universiti Putra\nproduces 1.3629 times more lift than the Learjet\nMalaysia (UPM) for granting Research\n60. The total drag of the joined-wing\nUniversity Grant Scheme (RUGS) No. 05-02-10-\nconfiguration aircraft after considering the\n0928RU; CC-91933, under which the present\nreduction of vortex drag due to the joined-\nresearch is carried out.\nconfiguration is 3.5 percent lower than the\nLearjet 60. Figs. 18 and 19 and Table 11 exhibit\nsuch comparison, which indicate that the Copyright Statement\nobjectives have been to a certain extent achieved.\nThe authors confirm that they, and/or their company or\nHowever, further study needs to be carried out to\norganization, hold copyright on all of the original material\nelaborate how joined-wing aircraft without any\nincluded in this paper. The authors also confirm that they\nuplift produced by the aft wing will not turn out have obtained permission, from the copyright holder of any\nto be as heavy as the conventional design. third party material included in this paper, to publish it as\npart of their paper. The authors confirm that they give\npermission, or have obtained permission from the copyright\nholder of this paper, for the publication and distribution of\nReferences\nthis paper as part of the ICAS2012 proceedings or as\nindividual off-prints from the proceedings.\n[1]. Wolkovitch, J., Joined Wing Aircraft, U.S. Patent\n3,942,747, March 1976.\n[2]. Wolkovitch, J., Joined Wing Aircraft, U.S. Patent\n4,365,773, Dec. 1982.\n[3]. Wolkovitch, J. The Joined Wing: An Overview,\nAIAA paper - 45285-587, J.Aircraft, 23(3), pp161-\n178, 1986.\n[4]. Samuels, M.F., "Structural Weight Comparison of a\nJoined Wing and a Conventional Wing," Journal of\nAircraft, Vol. 19, pp. 485-491, 1982.\n[5]. Gallman, J., Smith, S. and Kroo, I. Optimization of\nJoined-Wing Aircraft, J Aircraft, Vol. 30, No. 6,\n1993.\n[6]. Kroo, I., Gallman, J., and Smith, S. Aerodynamic\nand structural studies of joined-wing aircraft. Journal\nof Aircraft,Vol. 28, No. 1, 74–81, 1991.\n[7]. Gallman, J.W.,Smith, S. C.,and Kroo, I. M.\nOptimization of joined-wing aircraft. J. Aircr., 1993,\n30(6), 897–905.\n[8]. Kroo, I. M. Non-planar wing concept for increased\naircraft efficiency”, VKI Lecture, 2005.\n11'}

# %%
def shape_wordcloud(df, theme):
    word_freq = defaultdict(int)
    for entry in df[theme]:
        pairs = re.findall(r'\[([^,]+), (\d+)\]', entry)    # Extraire les paires mot-fréquence
        for word, freq in pairs:
            word_freq[word] += int(freq)

    wordcloud = WordCloud(width=600, height=600, background_color='white').generate_from_frequencies(word_freq)

    fig, ax = plt.subplots(figsize=(10, 10), facecolor='white')
    ax.imshow(wordcloud, interpolation='bilinear')
    plt.subplots_adjust(left=0.03, right=0.97, top=0.97, bottom=0.03)
    plt.axis('off')

    image_stream = io.BytesIO()
    plt.savefig(image_stream, format='png')
    image_stream.seek(0)

    plt.close()

    return image_stream

# %%
def remove_stop_words(corpus) : 
  for text, val in corpus.items() : 
    tmp = val.split(' ')
    # print(tmp)
    for stop_word in english_stopwords:
      if stop_word in tmp:
        # print(stop_word)
        tmp.remove(stop_word)
    tmp = " ".join(tmp)
    # print(tmp)
    corpus[text] = tmp
  return corpus

# %%
import re
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
import nltk
from nltk.corpus import stopwords

# Download stopwords
nltk.download('stopwords')

# Get English stopwords
english_stopwords = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/vuhoangthuyduong/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
sections = remove_stop_words(sections)
sections
# Out:
# {'1 Introduction': 'present work contribute to concept of\nThe joined-wing[1, 2] is innovative aircraft “Better, Lighter, Faster, Cheaper Greener”\nconfiguration rear wing a tip that Joined-Wing Business-Jet aircraft. “Better”\nsweeps forward to join the trailing edge the means the aircraft to conceptually designed\nmain wing. The rear wing (aft wing tail) is possesses superior aerodynamic\nused pitch control and a structural performance as considerably good rate of\nsupport for the forward wing. When compared to climb and endurances, takeoff and landing\na conventional wing-tail configuration, several distances, lower stalling velocity, and reduced\nadvantages predicted for joined-wings drag, among others. “Faster” means that the\n[3 - 9]. The potential for lower structural weights aircraft is able to fly a high speed, getting from\n1Kim Ern Foong and Harijono Djojodihardjo\none point to another a much shorter time. In Table 1. A sample of Selected Business Jets\nconsequence, the aircraft should be able to fly in Statistics (detailed analysis is elaborated in [11])\nhigh-subsonic or transonic cruising speeds. If the\njoined-wing aircraft conceived should have\nconsiderably good aerodynamic performance,\nmore fuel saving and economical engines with\nreduced thrust be required, thus saving the\naircraft’s operating cost, hence the word\n“Cheaper” comes place. Greener aircraft\nobjectives could be gained the previous\nadvantages, as well as novel concept in the\nholistic design approach. Various authors [3-9]\nhave established and verified the advantages of\nJoined Wing Aircraft as compared to conventional\nCantilevered Wing-Tail Design, such as lighter\nweight wing structure, better directional stability and\ncontrollability, lower induced drag, improved\naeroelastic characteristics and improved space for\nfuel, motivates the present work as well as\nposes a challenge for the conceptual design efforts. In\nsummary, the objectives of the present work to Table 2. Business Jet Specifications as outcome\ncarry conceptual design and aerodynamic study of the statistical analysis\na joined-wing configuration aircraft that possesses\nbetter aerodynamic performance in terms of increased\nIntended\nlift and reduced drag and lighter as compared to Parameters Unit Baseline Improveme\nnt\nconventional business jet of similar size, passenger\nNo. of Passengers Person 9 9\nand payload capability, and to arrive at a\nRange n mile 2,104.00 2,500.00\nstructurally robust joined wing configuration.\nMaximum Takeoff\nlb 21,270.18 20,000.00\nGross Weight\nCruise Speed mph 520.70 600.00',
#  '2 Statistical Studies for Reference Aircraft': 'Empty Weight lb 14,420.00 13,000.00\nA comprehensive statistical study carried Service Ceiling ft 46,218.25 48,000.00\nsearch candidate business jets to 10,500,000.0\nPrice USD 10,959,115.50\n0\nutilized reference establishing design\nLength ft 53.87 52.00\nrequirements objectives (DR&O), in-lieu of\nHeight ft 17.44 16.00\nmarket study. The design parameters and\nWing span ft 54.72 54.00\nperformance specifications several business jet\nwere obtained online literatures. One of Wing area ft 354.84 350.00\nthese candidate business jets is selected as Rate of Climb ft/min 3568.32 3,600.00\nconceptual design target, subject to Takeoff Distance ft 4,285.91 4,000.00\noverriding considerations, and reflects the\nLanding Distance ft 3,086.21 3,000.00\nspecific DR&O based customer requirements,\ncertification and requirements. For such\nFor the interest of objectivity, reference\npurpose, host of business jet aircraft data Business Jet be referred to in the present\nbeen compiled and summarized in Table 1. Based\nstudy as Reference Conventional Business Jet\non statistical analysis on trends and state of (RCBJ). It may be noted the specification\nthe art, a Business Jet specifications is\nparameters of selected RCBJ has a range of\ndescribed in Table 2 is obtained. values Learjet 45 and Learjet 60, which\nfor further assessment of the design study, will be\nreferred.\n2CONCEPTUAL DESIGN AND AERODYNAMIC STUDY\nOF JOINED-WING BUSINESS JET AIRCRAFT\nThe design considerations include mission\nprofile, weight and weight fraction and wing\nloading determination, airfoil selection, thrust\nloading, engine selection, forewing sizing, centre\nof gravity determination, aft wing (horizontal\ntail) and fuselage sizing, and landing\ngear/undercarriage configuration determination.\nFig. 1. Learjet 60 as reference aircraft [12]\nFig.F 1ig. . S2c. h Semchaetmica otifc hoef tJhoein Jeodin-Wedi-nWg iBnugs iness\nBusineJ se st A Jei tr c Ara irf ct\nraft\nFig. 3. Summary of Conceptual Design\nApproach',
#  '3 Systematic and Methodology': ': Conceptual Further computational iterations analysis\nDesign Approach. follow obtain better estimation aircraft\nweight, lift and drag. In addition, structural and\nThis work organized systematically to cover\nstability analysis also carried in\nthe authors’ design philosophy of of Raymer\nsubsequent iterative cycles. A performance\n[13]. The state of art and progress of the\nanalysis is carried out followed by\njoined-wing aircraft technology and development\ncomprehensive assessment of the design\nare considered. Following statistical analysis,\nspecifications outcome. This design philosophy\nperformance and design parameters of various\nis summarized Figure 3. Following such\nbusiness jet aircrafts are carefully assessed and\ndesign philosophies a preliminary step toward\nanalyzed to arrive acceptable target aircraft\nCDIO, Lean Aircraft Initiatives, and “Better,\nDR&O and design specifications, is then\nLighter, Faster, Cheaper and Greener” aircraft\nreferred to as the RCBJ. The DR&O of this\ndemanded global energy and environmental\nRCBJ guide the present conceptual design to\nconcerns, the problem statement of work is to\narrive at performance and design parameters of\nconceptually design a joined-wing business jet\nthe desired Joined-Wing Business Jet (JWBJ).\n3Kim Ern Foong and Harijono Djojodihardjo\naircraft that produces lift and less drag, but\nyet is lighter the conventional business jet of\nsimilar size.\nMission profile determination and Flight\n37,000 ft/11,100m\nenvelope of the joined-wing configuration\n35,000 ft/ 10,500m 3\naircraft 2 4\nThe flight envelope, V-n diagram, is 34,000 ft/10,200m\ndetermined following FAR’s regulations and\nmission profile. The regulations provide a\n5 6\nmethod to determine the maximum load factor\n0 1\nlimit. The structure is designed to the ultimate 1800 seconds\nFig. 4. Mission Profile of the Target JWBJ\nload factor a factor of safety of 1.5 above\nthe limit load. Basically the V-n diagram is based\non two limitations, namely aerodynamic and',
#  '4 Conceptual Design Work Progress and': 'structural limits. Some parameters are\nOutcome\nincorporated the V-n diagram calculations. The\nimproved refined values used instead of 4.1 Aircraft Sizing; Weight and Weight Fraction\nthe initial estimate. Determination\nThe detail of the design calculation is\nTable 3. Parameters considered in flight envelope comprehensively described in Kim[ 11]. The total\ncalculations weight of the payload, W determined to\npayload\nbe 1635.00kg (3604.56lbs), the range 4630 km\nand cruise velocity 550 mph. The typical\nParameters Units Value Remarks \uf0e6 L \uf0f6\nmaximum lift-to-drag ratio, of RCBJ is\n\uf0e7 \uf0f7\n\uf0e8D\uf0f8\n17.5 Initial estimate Max\n\uf0e6 L \uf0f6\nObtained from\n14. An improvement in\n\uf0e7 \uf0f7\nof 25% desired.\n1.512\nairfoil\n\uf0e8D\uf0f8\nMax\nForewing Area, S 743.5649\nAssuming the JWBJ acquire\n\uf0e6 L \uf0f6\n=1.75,\n(forewing) 0.07423\nF efr fo im\ncie\nO ncs yw mald\net\nhsp oa dn \uf0e7 \uf0e8D\uf0f7\n\uf0f8 Max\nOswald Span Efficiency Oswald span Lift-to-drag ratio cruise 15.155.\n0.4549\nFactor, (forewing) efficiency method The wing loading is computed based two\n(total aircraft) 0.0100094 C buo im ldp uo pn ent constraints: (a) Stall velocity, v stall and (b)\nlanding distance. Assuming approach speed of\nCruise altitude 35000\nsimilar Learjet 60 , the velocity is estimated to\nCruise density 0.0007382 be 155.9km/hr. Typical cruise altitude of h cruise of\n35000ft and cruise Mach number of 0.8290 can\nCruise velocity 806.6667\nbe assumed.\nImproved value\nthrough lift and\nWing loading based on Stall velocity\nWeight mid-cruise 20019.0179\nstructural\nconsiderations\nTo search the desired C Lmax.value and C\nL\n,\nWing loading 30.5073 Improved value appropriate selection of airfoil to be made.\nOther parameters are estimated using those\napplicable to RCBJ.\nThrust loading 0.2414 Improved value',
#  '5 Airfoil selection': 'In order start selecting suitable airfoil for\nconceptual design purposes, airfoil analysis are\n4CONCEPTUAL DESIGN AND AERODYNAMIC STUDY\nOF JOINED-WING BUSINESS JET AIRCRAFT\ncarried using basic principles available simple ratio lift curve slope due to wing tip (trailing)\ncomputer program (for example designFOIL). vortices qualitatively exhibited Fig. 5.\nFollowing historical trends, NACA 5-digit series .\nwere used extensively in business jets. Thus, the\nNACA 5-digit series airfoils selected. NACA\n66013-43 airfoil selected due to its\nconventionality and as a baseline.\nA parametric study carried out starting\nwith NACA66013-43 series, and values varied\nto find the best airfoil. Such parametric study is\ncarried out varying the first, second and third, fourth\nand fifth digits, and variations. Typical finding\nis illustrated Table 4.\n\uf061\nTable 4. Typical Outcome airfoil parametric\nstudy result Fig.5. The effect of aspect ratio to lift\nVariation of the lift coefficient indicated by The figure shows the relation between\nthe first digit\n[α=0˚] and the wetted aspect ratio. From graph and\nLift Drag Moment others available on various data bases, a first estimate\nType of airfoil Coeffic Coeffici Coefficie on the wingspan and aspect ratio made.\nient ent nt\nThe choice of wing dihedral angle also be\nNACA46013-43 0.436 0.0070 -0.064\nmade, guided by dihedral angle guidelines as\nNACA56013-43 0.544 0.0072 -0.080\ngiven by Raymer [13]. Since joined-wing\nNACA66013-43 0.653 0.0073 -0.097\nconfiguration is of low wing and is a subsonic\nNACA76013-43 0.724 0.0074 -0.113 swept wing, the dihedral angles should be within\nNACA86013-43 0.766 0.0076 -0.129 3 to 7 degrees.\nThe forewing is placed in such as way the\nFor the example displayed in Table 4, the aerodynamic centre of the wing is in line the\nsuitable airfoil is NACA66013-43 it a\ncentre of gravity of the fuselage, as schematically\nconsiderably high lift coefficient and also a drag\nillustrated by Fig.6..\ncoefficient that is large. At the present stage,\nonly parametric study design iteration and\noptimization has carried out; structured\noptimization be carried out incorporating wing\ntwist and other structural considerations. Wing\nloading study is exemplified in Table 5.\nTable 5, Wing Loading estimates\nWing loading,\nConstraints Remarks\nW/S [lb/ft2]\nLower wing\nStall Velocity 30.2390\nloading\nLanding Higher wing\n85.9830\nDistance loading\nFig. 6. Schematic Diagram of Forewing\nBased on such parametric study, forewing sizing Placement\nis carried out, followed by the computation of\nwing area and aspect ratio. Trade-off study is\nmade to choose the appropriate aspect ratio,\ntaking considerations the effect of aspect\n5Kim Ern Foong and Harijono Djojodihardjo\nFig. 8. NACA 66013-43 airfoil\nFig. 7: Schematic Diagram of Fuselage Design\nand dimensioning\nTable 6. Calculation of CG (without forewings)\nFig. 9. Airfoil Maximum Thickness Root Chord\n(dimensions in feet)\nt h g ie W\nf e p T\n] g k [ h\ng ie W t in U\ny titn\na u Q\n]g k\n[ la t o T\n]m b\nl[ la t o T\ne\ns o n o\nr f e c n a t s\niD]tf [\nm u t a ∑\nAir crews 80 2 160 352.739619 8.02 2828.972\nPassengers 80 9 720 1587.32856 24.22 38445.1\nCabin\n80 2 160 352.73968 24.22 8543.355\ncrew\nCabin\ncrew\nunchecked 30 2 60 132.27738 39.34 5203.792 Fig. 10. Aileron sizing and placement\nbaggage\nThrough computation using strip theory, on-line\nPassenger\nunchecked 5 9 45 99.208035 24.22 2402.819 simple airfoil computational method and panel\nbaggage\nmethod, wing lift and its parametric optimization is\nAir crew carried out. The spanwise sectional lift distribution\n40 2 80 176.36984 8.02 1414.486\nluggage\nof the Conceptual JWBJ is exhibited in Figs. 11 and\nPassenger\nchecked 30 9 270 595.24821 39.34 23417.06 12..\nluggage\nEngine 448.1492 2 896.29 1976.00034 40.6 80225.61\n5271.91166 162481.2\nForewing Airfoil\nThe airfoil chosen for the forewing is . NACA\n66013-43 airfoil, ...
#  '7 Flight envelope of the joined': '-wing\nFig. 18 Flight Envelope JWBJ 35000 ft\nconfiguration aircraft\nThe flight envelope, V-n diagram, is\nFlight Envelope of RCBJ\ndetermined according regulations FAR’s\nand the mission profile. The regulations\nprovide method to determine the maximum\nlimit load factor. The structure designed to the\nultimate load factor a factor of safety\nof 1.5 the limit load. Basically v-n diagram\nwere based two limitations, namely\naerodynamic limits structural limits. Some of\nthe parameter involved in the V-n diagram\ncalculations. The improved and refined values are\nFig. 19 Flight Envelope of RCBJ at 35000 ft\nused instead of the initial estimate.\nTable 11. Summary of JWBJ Design\nTable 10 Parameters incorporated in flight Specification compared to RCBJ.\nenvelope calculations\nJoined-Wing\nConfiguration\nParameter Unit Aircraft RCBJ\nParameters Units Value Remarks\nNumber of passengers - 9 9\n(L/D)max 17.5 Initial estimate\nObtained from Range n mile 2500.6252 2409.0000\n(CL)max 1.512\nairfoil\nForewing Area, S ft2 743.5649\nMaximum Range n mile 2601.5674 2450.0000\nMaximum Takeoff Gross\nFrom Oswald Weight lbm 22684.1299 23500.0000\n(forewing) 0.07423 span efficiency\nmethod Cruise speed (35000ft) mph 550.0000 484.0000\nOswald Span Efficiency\n0.4549\nOswald span\nStall velocity at sea-level ft/s 130.4044 129.8300\nFactor, (forewing) efficiency method\nComponent Stall velocity at 35000ft ft/s 180.0000 -\n(total aircraft) 0.0100094\nbuildup Maximum Operating\nCruise altitude ft 35000 Speed ft/s 1030.0000 765.6000\nCruise density Slug/ft3 0.0007382 Serving Ceiling ft 52651.8000 51000.0000\nCruise velocity ft/s 806.6667 Takeoff Distance ft 2603.7323 4000\nImproved value Landing Distance ft 2339.9544 2660.76\nthrough lift and\nWeight at mid-cruise lb 20019.0179\nstructural Fuselage Length ft 57.8483 58.6667\nconsiderations\nWing loading (W/S) lb/ ft2 30.5073 Improved value Wing Span ft 76.4200 47.7500\nThrust loading (T/W) lbf/lbm 0.2414 Improved value Wing Area (Forewing) sq. ft 743.5649 264.5\nWing Area (Aft wing) sq. ft 310.2954\n10CONCEPTUAL DESIGN AND AERODYNAMIC STUDY\nOF JOINED-WING BUSINESS JET AIRCRAFT',
#  '6 Conclusions': '[9]. Kroo, I.M. Drag Due To Lift: Concepts for\nPrediction Reduction, Annu. Rev. Fluid Mech.\nAs concluding remarks, results obtained 33:587–617, 2001.\n[10]. Cuerno-Rejado, C., Alonso-Albir, L. and Gehse, P.\ndesigns compared aim of\nConceptual design medium-sized joined-wing\nconcluding the joined-wing configuration has\naircraft, Proc. IMechE Vol. 224 Part G: J. Aerospace\nmet the objectives set in the beginning of this\nEngineering,2007.\nwork. To end, the comparison will be [11]. Kim, E.F., Design and aerodynamic study of Joined-\nestablished based four technological aspects. Wing Aircraft, Thesis, Aerospace Engineering\nDepartment, Universiti Putra Malayisa, 2011.\nIt important note the conclusions drawn\n[12]. Learjet 60, Wikimedia Foundation, Inc. 22 March\nfrom this study based on simplistic\n2011. 29 March 2011, http://en.wikipedia.org/\naerodynamic and structural assumptions that\nwiki/Learjet_60, accessed 15 June 2012.\nshould be accurately substantiated in future [13]. Raymer, D.P. Aircraft Design: A Conceptual\nworks. Approach, 2nd Ed.. AIAA, USA, 1992.\nFrom the analysis carried out in this work, can\nbe concluded that, the JWBJ joined-wing\nAcknowledgement\nconfiguration aircraft is 5.0716 percent lighter\nthan the reference Business Jet (RCBJ) and\nThe authors would like to thank Universiti Putra\nproduces 1.3629 times more lift the Learjet\nMalaysia (UPM) granting Research\n60. The total drag of the joined-wing\nUniversity Grant Scheme (RUGS) No. 05-02-10-\nconfiguration aircraft considering the\n0928RU; CC-91933, the present\nreduction of vortex drag due to the joined-\nresearch is carried out.\nconfiguration is 3.5 percent lower than the\nLearjet 60. Figs. 18 and 19 and Table 11 exhibit\nsuch comparison, which indicate that the Copyright Statement\nobjectives to a certain extent achieved.\nThe authors confirm that they, and/or company or\nHowever, study needs to be carried out to\norganization, hold copyright on of the original material\nelaborate joined-wing aircraft without any\nincluded in this paper. The authors also confirm that they\nuplift produced the aft wing will turn out have obtained permission, the copyright holder of any\nto be heavy as the conventional design. third party material included in this paper, to publish it as\npart of their paper. The authors confirm that give\npermission, have obtained permission from the copyright\nholder of this paper, for the publication and distribution of\nReferences\nthis paper as part of the ICAS2012 proceedings or as\nindividual off-prints from the proceedings.\n[1]. Wolkovitch, J., Joined Wing Aircraft, U.S. Patent\n3,942,747, March 1976.\n[2]. Wolkovitch, J., Joined Wing Aircraft, U.S. Patent\n4,365,773, Dec. 1982.\n[3]. Wolkovitch, J. The Joined Wing: An Overview,\nAIAA paper - 45285-587, J.Aircraft, 23(3), pp161-\n178, 1986.\n[4]. Samuels, M.F., "Structural Weight Comparison of a\nJoined Wing and a Conventional Wing," Journal of\nAircraft, Vol. 19, pp. 485-491, 1982.\n[5]. Gallman, J., Smith, S. and Kroo, I. Optimization of\nJoined-Wing Aircraft, J Aircraft, Vol. 30, No. 6,\n1993.\n[6]. Kroo, I., Gallman, J., and Smith, S. Aerodynamic\nand structural studies of joined-wing aircraft. Journal\nof Aircraft,Vol. 28, No. 1, 74–81, 1991.\n[7]. Gallman, J.W.,Smith, S. C.,and Kroo, I. M.\nOptimization of joined-wing aircraft. J. Aircr., 1993,\n30(6), 897–905.\n[8]. Kroo, I. M. Non-planar wing concept for increased\naircraft efficiency”, VKI Lecture, 2005.\n11'}

# %%
english_stopwords
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
def visualize(sections, label):
      
    wordcloud = WordCloud(width=500, height=400).generate(sections[label])
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.title(label)

# %%
visualize(sections,  '7 Flight envelope of the joined')

# %%
wordcloud = WordCloud(width=500, height=400).generate(pdf_text)
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 499.5, 399.5, -0.5)
